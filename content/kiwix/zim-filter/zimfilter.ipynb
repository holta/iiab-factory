# %% [markdown]
# ## Modifying ZIM Files
#
# #### The Larger Picture
# * Kiwix scrapes many useful sources, but sometimes the chunks are too big for IIAB.
# * Using the zimdump program, the highly compressed ZIM files can be flattened into a file tree, modified, and then re-packaged as a ZIM file.
# * This Notebook has a collection of tools which filters the content into a new smaller zim selected by youtube views/per year.

# %% [markdown]
# #### How to Use this notebook
# * The zimdump program (at https://github.com/openzim/zim-tools) needs to be compiled from source.
# * A bash script makes is easy to compile zimtools (which contains zimdump) on Ubuntu 20.04. There are instructions for the compilation at the github url. In a terminal, do the following:
#
# ```
# cd /opt/iiab/iiab-factory/content/kiwix/generic/
# sudo ./install-zim-tools.sh
#
# ```
# * This ```zimfilter``` program can be set up into a python virtual environment using a role in the iiab-factory repository:
#
# ```
# sudo ./runrole youtube
# ```

# %% [markdown]
# * **Some conventions**: Jupyter does not want to run as root. We will create a file structure that exists in the users home directory -- so the application will be able to write all the files it needs to function.
# ```
# <PREFIX>
# ├── default_config.yaml
# ├── new-zim
# ├── output_tree
# ├── proof
# ├── tree
# ├── working
# └── zim-src
# ```
# In general terms, this program will dump the zim data into "tree", modify it, gather additional data into "working", copy the desired videos to "output_tree"
# , and create a ZIM file in "new_zim". After the new ZIM is created, it is re-dumped to "proof".
# * For testing purposes, the user will need to link from the server's document root to her home directory (so that the nginx http server in IIAB will serve the candidate in "tree):
#
# ```
# cd
# mkdir -p zims
# ln -s /home/<user name>/zims/library/www/html/zims
# ```

# %% [markdown]
# #### Declare input and output
# * The ZIM file names tend to be long and hard to remember. The PROJECT_NAME, initialized below, is used to create path names. All of the output of the zimdump program is placed in \<home\>/zims/\<PROJECT_NAME\>/tree. All if the intermediate downloads, and data, are placed in \<home\>/zims/\<PROJECT_NAME\>/working. If you use the IIAB Admin Console to download ZIMS, you will find them in /library/zims/content/.

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
import os,sys
import json
import youtube_dl
import pprint as pprint
from types import SimpleNamespace
import subprocess
from ruamel.yaml import YAML 
from pprint import pprint

# Get the current project from it's pointer in iiab-factory repo
FACTORY_REPO = '/opt/iiab/iiab-factory'
PREFIX = '/library/www/html/zims'
#PREFIX = '/ext/zims'

current_project = FACTORY_REPO + '/content/kiwix/zim-filter/current_project'
if not os.path.isfile(current_project):
    print(f'\"current_project\" file is missing: {current_project}')
    sys.exit(1)
with open(current_project,'r') as fp:
    project_name = fp.read().strip().split('/')
    if len(project_name) > 0:
        prefix = project_name[:-1]
        project_name = project_name[-1]
lookfor = f"{PREFIX}/{project_name}/default_config.yaml"
dflt_cfg = f'{FACTORY_REPO}/content/kiwix/zim-filter/default_filter.yaml'
yml = YAML()
if not os.path.isfile(lookfor):
    with open(dflt_cfg,'r') as fp:
        cfg = yml.load(fp)
    cfg['PREFIX'] = PREFIX
    cfg['PROJECT_NAME'] = project_name
    with open(lookfor,'w') as newfp:
        yml.dump(cfg,newfp) 
else:
    with open(lookfor,'r') as fp:
        cfg = yml.load(fp)

PROJECT_NAME = cfg['PROJECT_NAME']
SOURCE_URL = cfg['SOURCE_URL']
CACHE_DIR = PREFIX + '/youtube/cache'
if not os.path.isdir(CACHE_DIR):
   os.makedirs(CACHE_DIR)
TARGET_SIZE = cfg['TARGET_SIZE']  #10GB

# The rest of the paths are computed and represent the standard layout
WORKING_DIR = PREFIX + '/' + PROJECT_NAME + '/working'
PROJECT_DIR = PREFIX + '/' + PROJECT_NAME + '/tree'
OUTPUT_DIR = PREFIX + '/' + PROJECT_NAME + '/output_tree'
SOURCE_DIR = PREFIX + '/' + PROJECT_NAME + '/zim-src'
NEW_ZIM_DIR = PREFIX + '/' + PROJECT_NAME + '/new-zim'
PROOF_DIR = PREFIX + '/' + PROJECT_NAME + '/proof'
dir_list = ['working','output_tree','tree','../youtube/cache/video_json','zim-src','new-zim','proof']
for f in dir_list: 
    if not os.path.isdir(PREFIX + '/' + PROJECT_NAME +'/' + f):
       os.makedirs(PREFIX + '/' + PROJECT_NAME +'/' + f)

# Input the full path of the downloaded ZIM file
ZIM_PATH = SOURCE_DIR
zim_path_contents = os.listdir(SOURCE_DIR)
if zim_path_contents:
    ZIM_PATH = SOURCE_DIR + '/' + zim_path_contents[0]
else:
    if SOURCE_URL.find('/library/zims') == 0:
        os.symlink(SOURCE_URL,SOURCE_DIR)
    else:
        cmd = 'wget -P %s %s'%(SOURCE_DIR,SOURCE_URL)
        print('command:%s'%cmd)
        subprocess.run(cmd,shell=True)
        
# abort if the input file cannot be found
if not os.path.exists(ZIM_PATH):
    print('%s path not found. Quitting. . .'%ZIM_PATH)
    exit

# %%
print(f'{PREFIX},{PROJECT_DIR},{project_name}')
# Out:
# /library/www/html/zims,/library/www/html/zims/teded/tree,teded

# %%
# The following command will zimdump to the "tree" directory
#  Despite the name, removing namespaces seems unnecessary, and more complex
# It will return without doing anything if the "tree' is not empty
print('Using zimdump to expand the zim file to %s'%PROJECT_DIR)
progname = '%s/content/kiwix/zim-filter/de-namespace.sh'%(cfg['FACTORY_REPO'])
cmd = "%s %s %s"%(progname,ZIM_PATH,PREFIX + '/' + PROJECT_NAME)
print('command:%s'%cmd)
subprocess.run(cmd,shell=True,capture_output=True)
# Out:
# Using zimdump to expand the zim file to /library/www/html/zims/teded/tree
# command:/opt/iiab/iiab-factory/content/kiwix/zim-filter/de-namespace.sh /library/www/html/zims/teded/zim-src/teded_en_all_2021-04.zim /library/www/html/zims/teded
# CompletedProcess(args='/opt/iiab/iiab-factory/content/kiwix/zim-filter/de-namespace.sh /library/www/html/zims/teded/zim-src/teded_en_all_2021-04.zim /library/www/html/zims/teded', returncode=0, stdout=b'', stderr=b"+ set -e\n+ '[' 2 -lt 2 ']'\n+ '[' '!' -f /library/www/html/zims/teded/zim-src/teded_en_all_2021-04.zim ']'\n+ rm -rf /library/www/html/zims/teded/tree\n+ mkdir -p /library/www/html/zims/teded/tree\n+ echo 'This de-namespace file reminds you that this folder will be overwritten?'\n+ zimdump dump --dir=/library/www/html/zims/teded/tree /library/www/html/zims/teded/zim-src/teded_en_all_2021-04.zim\n+ mv /library/www/html/zims/teded/tree/I/assets /library/www/html/zims/teded/tree/I/banner.jpg /library/www/html/zims/teded/tree/I/channels /library/www/html/zims/teded/tree/I/favicon.jpg /library/www/html/zims/teded/tree/I/profile.jpg /library/www/html/zims/teded/tree/I/videos /library/www/html/zims/teded/tree\n+ '[' -d I ']'\n+ cp -rp /library/www/html/zims/teded/tree/A/1000_tedtalks_6_words_sebastian_wernicke.html /library/www/html/zims/teded/tree/A/3_stories_of_local_eco_entrepreneurship_majora_carter.html /library/www/html/zims/teded/tree/A/3_things_i_learned_while_my_plane_crashed_ric_elias.html /library/www/html/zims/teded/tree/A/3_tips_to_boost_your_confidence_ted_ed.html /library/www/html/zims/teded/tree/A/404_the_story_of_a_page_not_found_renny_gleeson.html /library/www/html/zims/teded/tree/A/4_lessons_from_robots_about_being_human_ken_goldberg.html /library/www/html/zims/teded/tree/A/5_tips_to_improve_your_critical_thinking_samantha_agoos.html /library/www/html/zims/teded/tree/A/8_traits_of_successful_people_richard_st_john.html /library/www/html/zims/teded/tree/A/a_3d_atlas_of_the_universe_carter_emmart.html /library/www/html/zims/teded/tree/A/a_3_minute_guide_to_the_bill_of_rights_belinda_stutzman.html /library/www/html/zims/teded/tree/A/a_40_year_plan_for_energy_amory_lovins.html /library/www/html/zims/teded/tree/A/a_brief_history_of_alcohol_rod_phillips.html /library/www/html/zims/teded/tree/A/a_brief_history_of_banned_numbers_alessandra_king.html /library/www/html/zims/teded/tree/A/a_brief_history_of_cannibalism_bill_schutt.html /library/www/html/zims/teded/tree/A/a_brie_f_history_of_cheese_paul_kindstedt.html /library/www/html/zims/teded/tree/A/a_brief_history_of_chess_alex_gendler.html /library/www/html/zims/teded/tree/A/a_brief_history_of_divorce_rod_phillips.html /library/www/html/zims/teded/tree/A/a_brief_history_of_dogs_david_ian_howe.html /library/www/html/zims/teded/tree/A/a_brief_history_of_goths_dan_adams.html /library/www/html/zims/teded/tree/A/a_brief_history_of_melancholy_courtney_stephens.html /library/www/html/zims/teded/tree/A/a_brief_history_of_numerical_systems_alessandra_king.html /library/www/html/zims/teded/tree/A/a_brief_history_of_plastic.html /library/www/html/zims/teded/tree/A/a_brief_history_of_plural_word_s_john_mcwhorter.html /library/www/html/zims/teded/tree/A/a_brief_history_of_religion_in_art_ted_ed.html /library/www/html/zims/teded/tree/A/a_brief_history_of_the_devil_brian_a_pavlac.html /library/www/html/zims/teded/tree/A/a_brief_history_of_video_games_part_i_safwat_saleem.html /library/www/html/zims/teded/tree/A/a_broken_body_isn_t_a_broken_person_janine_shepherd.html /library/www/html/zims/teded/tree/A/a_call_to_invention_diy_speaker_edition_william_gurstelle.html /library/www/html/zims/teded/tree/A/accents_by_denice_frohman.html /library/www/html/zims/teded/tree/A/a_census_of_the_ocean_paul_snelgrove.html /library/www/html/zims/teded/tree/A/a_child_of_the_state_lemn_sissay.html /library/www/html/zims/teded/tree/A/a_choreographer_s_creative_process_in_real_time_wayne_mcgregor.html /library/www/html/zims/teded/tree/A/a_cinematic_journey_through_visual_effects_don_levy.html /library/www/html/zims/teded/tree/A/a_civil_response_to_violence_emiliano_salinas.html /library/www/html/zims/teded/tree/A/a_clean_energy_proposal_race_to_the_top_jennifer_granholm.html /library/www/html/zi ...

# %% [markdown]
# * The next step is a manual one that you will need to do with your browser. That is: to verify that after the namespace directories were removed, and all of the html links have been adjusted correctly. Point your browser to <hostname>/zims/\<PROJECT_NAME\>/tree.
# * If everything is working, it's time to go fetch the information about each video from youtube.

# %%
ydl = youtube_dl.YoutubeDL()
print('Downloading metadata from Youtube')
downloaded = 0
skipped = 0
# Create a list of youtube id's
yt_id_list = os.listdir(PROJECT_DIR + '/videos/')
for yt_id in iter(yt_id_list):
    if os.path.exists(CACHE_DIR + '/video_json/' + yt_id + '.json'):
        # skip over items that are already downloadd
        skipped += 1
        continue
    with ydl:
       result = ydl.extract_info(
                'http://www.youtube.com/watch?v=%s'%yt_id,
                download=False # We just want to extract the info
                )
       downloaded += 1

    with open(CACHE_DIR + '/video_json/' + yt_id + '.json','w') as fp:
        fp.write(json.dumps(result))
    #pprint.pprint(result['upload_date'],result['view_count'])
print('%s skipped and %s downloaded'%(skipped,downloaded))
# Out:
# Downloading metadata from Youtube
# 1851 skipped and 0 downloaded

# %% [markdown]
# #### Playlist Navigation to Videos
# * On the home page that shows when viewing a ZIM, there is a drop down selector which lists about 70 cateegories (or playlists).
# * The value from that drop down is used to pick an entry in "-/assets/data.js", which in turn specifies the  youtube ID"s that are displayed when a selection is made.

# %%
def get_assets_data():
    # the file <root>/assets/data.js holds the category to video mappings
    outstr = '['
    data = {}
    with open(PROJECT_DIR + '/assets/data.js', 'r') as fp:
        line = fp.readline()
        while True:
            if line.startswith('var') or not line :
                if len(outstr) > 3:
                    # clip off the trailing semicolon
                    outstr = outstr[:-2]
                    try:
                        data[cat] = json.loads(outstr)
                    except Exception:
                        print('Parse error: %s'%outstr[:80])
                        exit
                cat = line[9:-4]
                outstr = '['
                if not line: break
            else:
                outstr += line
            line = fp.readline()
    return data

zim_category_js = get_assets_data()
#print(json.dumps(zim_category_js,indent=2))
def get_zim_data(yt_id):
    rtn_dict = {}
    for cat in  iter(zim_category_js.keys()):
        for video in range(len(zim_category_js[cat])):
            if zim_category_js[cat][video]['id'] == yt_id:
                rtn_dict = zim_category_js[cat][video]
                break
        if len(rtn_dict) > 0: break
    return rtn_dict
ans = get_zim_data('usdJgEwMinM')
#print(json.dumps(ans,indent=2))

# %% [markdown]
# #### The following Cell is subroutines and can be left minimized

# %%
from pprint import pprint
from pymediainfo import MediaInfo

def mediainfo_dict(path):
    try:
        minfo = MediaInfo.parse(path)
    except:
        print('mediainfo_dict. file not found: %s'%path)
        return {}
    return minfo.to_data()

def select_info(path):
    global data
    data = mediainfo_dict(path)
    rtn = {}
    infotrack = data.get('tracks',0)
    if infotrack == 0:
        return {}
    for index in range(len(infotrack)):
        #if index
        track = data['tracks'][index]
        if track['kind_of_stream'] == 'General':
            rtn['file_size'] = track.get('file_size',0)
            rtn['bit_rate'] = track.get('overall_bit_rate',0)
            rtn['time'] = track['other_duration'][0]
        if track['kind_of_stream'] == 'Audio':
            rtn['a_stream'] = track.get('stream_size',0)
            rtn['a_rate'] = track.get('maximum_bit_rate',0)
            rtn['a_channels'] = track.get('channel_s',0)
        if track['kind_of_stream'] == 'Video':
            rtn['v_stream'] = track.get('stream_size',0)
            rtn['v_format'] = track['other_format'][0]
            rtn['v_rate'] = track.get('bit_rate',0)
            rtn['v_frame_rate'] = track.get('frame_rate',0)
            rtn['v_width'] = track.get('width',0)
            rtn['v_height'] = track.get('height',0)
    return rtn

# %%
import sqlite3
class Sqlite():
   def __init__(self, filename):
      self.conn = sqlite3.connect(filename)
      self.conn.row_factory = sqlite3.Row
      self.conn.text_factory = str
      self.c = self.conn.cursor()
    
   def __del__(self):
      self.conn.commit()
      self.c.close()
      del self.conn

def get_video_json(path):
    with open(path,'r') as fp:
        try:
            jsonstr = fp.read()
            #print(path)
            modules = json.loads(jsonstr.strip())
        except Exception as e:
            print(e)
            print(jsonstr[:80])
            return {}
    return modules

def video_size(yt_id):
    return os.path.getsize(PROJECT_DIR + '/-/videos/' + yt_id + '/video.webm')

def make_directory(path):
    if not os.path.exists(path):
        os.makedirs(path)

def download_file(url,todir):
    local_filename = url.split('/')[-1]
    r = requests.get(url)
    f = open(todir + '/' + local_filename, 'wb')
    for chunk in r.iter_content(chunk_size=512 * 1024):
        if chunk:
            f.write(chunk)
    f.close()
    
from datetime import datetime
def age_in_years(upload_date):
    uploaded_dt = datetime.strptime(upload_date,"%Y%m%d")
    now_dt = datetime.now()
    days_delta = now_dt - uploaded_dt
    years = days_delta.days/365 + 1
    return years

# %% [markdown]
# #### Create a sqlite database which collects Data about each Video
# * We've already downloaded the data from YouTube for each Video. So get the items that are interesing to us. Such as size,date uploaded to youtube,view count

# %%
def initialize_db():
    sql = 'CREATE TABLE IF NOT EXISTS video_info ('\
            'yt_id TEXT UNIQUE, zim_size INTEGER, view_count INTEGER, age INTEGER, '\
            'views_per_year INTEGER, upload_date TEXT, duration TEXT, '\
            'height INTEGER, width INTEGER,'\
            'bit_rate TEXT, format TEXT, '\
            'average_rating REAL,slug TEXT,title TEXT)'
    db.c.execute(sql)
    
print('Creating/Updating a Sqlite database with information about the Videos in this ZIM.')
print(WORKING_DIR)
db = Sqlite(WORKING_DIR + '/zim_video_info.sqlite')
initialize_db()
sql = 'select count() as num from video_info'
db.c.execute(sql)
row = db.c.fetchone()
if row[0] == len(yt_id_list):
    print('skipping update of sqlite database. Number of records equals number of videos')
else:
    for yt_id in iter(yt_id_list):
        # some defaults
        age = 0
        views_per_year = 1
        # fetch data from assets/data.js
        zim_data = get_zim_data(yt_id)
        if len(zim_data) == 0: 
            print('get_zim_data returned no data for %s'%yt_id)
        slug = zim_data['slug']

        # We already have youtube data for every video, use it 
        data = get_video_json(CACHE_DIR + "/video_json/" + yt_id + '.json')
        if len(data) == 0:
            print('get_video_json returned no data for %s'%yt_id)
        vsize = data.get('filesize',0)
        view_count = data.get('view_count',0)
        upload_date = data.get('upload_date','')
        average_rating = data.get('average_rating',0)
        title = data.get('title','unknown title')
        # calculate the views_per_year since it was uploaded
        if upload_date != '':
            age = round(age_in_years(upload_date))
            views_per_year = int(view_count / age)

        # interogate the video itself
        filename = PROJECT_DIR + '/videos/' + yt_id + '/video.webm'
        if os.path.isfile(filename):
            vsize = os.path.getsize(filename)
            #print('vsize:%s'%vsize)
            selected_data = select_info(filename)
            if len(selected_data) == 0:
                duration = "not found"
                bit_rate = "" 
                v_format = ""
                v_height = ""
                v_width = ""
            else:
                duration = selected_data['time']
                bit_rate = selected_data['bit_rate']
                v_format = selected_data['v_format']
                v_height = selected_data['v_height']
                v_width = selected_data['v_width']

        # colums names: yt_id,zim_size,view_count,views_per_year,upload_date,duration,
        #         bit_rate, format,average_rating,slug
        sql = 'INSERT OR REPLACE INTO video_info VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?)'
        db.c.execute(sql,[yt_id,vsize,view_count,round(age),views_per_year,upload_date, \
                          duration,v_height,v_width,bit_rate,v_format,average_rating,slug,title, ])
    db.conn.commit()
    print(yt_id,vsize,view_count,views_per_year,upload_date, \
                          duration,bit_rate,v_format,average_rating,slug,round(age))
# Out:
# Creating/Updating a Sqlite database with information about the Videos in this ZIM.
# /library/www/html/zims/teded/working
# skipping update of sqlite database. Number of records equals number of videos

# %% [raw]
# sqlite_db = WORKING_DIR + '/zim_video_info.sqlite'
# !sqlite3 {sqlite_db} '.headers on' 'select * from video_info limit 2'

# %% [markdown]
# #### Select the cutoff using view count and total size
# * Order the videos by view countper year. Then select the sum line in the that has the target sum.

# %%
import pandas as pd
from IPython.display import display 
global tot_sum

def human_readable(num):
    # return 3 significant digits and unit specifier
    num = float(num)
    units = [ '','K','M','G']
    for i in range(4):
        if num<10.0:
            return "%.2f%s"%(num,units[i])
        if num<100.0:
            return "%.1f%s"%(num,units[i])
        if num < 1000.0:
            return "%.0f%s"%(num,units[i])
        num /= 1024.0

sql = 'select slug,zim_size,views_per_year,view_count,duration,upload_date,'\
       'format,width,height,bit_rate from video_info order by views_per_year desc'
tot_sum = 0
db.c.execute(sql)
rows = db.c.fetchall()
row_list = []
boundary_views_per_year = 0
for row in rows:
    tot_sum += row['zim_size']
    row_list.append([row['slug'][:60],human_readable(row['zim_size']),\
                              human_readable(tot_sum),human_readable(row['view_count']),\
                              human_readable(row['views_per_year']),\
                              row['upload_date'],row['duration'],row['bit_rate']])
    if tot_sum > TARGET_SIZE and boundary_views_per_year == 0:
        boundary_views_per_year = row['views_per_year']
print('%60s %6s %6s %6s %6s %8s %8s'%('Name','Size','Sum','Views','Views','Date  ','Duration'))
print('%60s %6s %6s %6s %6s %8s %8s'%('','','','','/ yr','',''))
tot_sum = 0
for row in rows:
    tot_sum += row['zim_size']
    print('%60s %6s %6s %6s %6s %8s %8s'%(row['slug'][:60],human_readable(row['zim_size']),\
                              human_readable(tot_sum),human_readable(row['view_count']),\
                              human_readable(row['views_per_year']),\
                              row['upload_date'],row['duration']))
#df = pd.read_sql(sql,db.conn)
#df = pd.DataFrame(row_list,columns=['Name','Size','Sum','Views','Views','Date','Duration','Bit Rate'])
#display(df)
# Out:
#                                                         Name   Size    Sum  Views  Views   Date   Duration
#                                                                                     / yr
#                       how_thor_got_his_hammer_scott_a_mellor  8.02M  8.02M  10.0M  3.34M 20190107 4 min 51 s
#           can_you_solve_the_prisoner_hat_riddle_alex_gendler  6.65M  14.7M  20.1M  2.87M 20151005 4 min 34 s
#                 which_is_stronger_glue_or_tape_elizabeth_cox  12.6M  27.3M  11.1M  2.76M 20180430 4 min 50 s
#      what_are_those_floaty_things_in_your_eye_michael_mauser  6.76M  34.0M  18.9M  2.70M 20141201 4 min 4 s
#                  is_marijuana_bad_for_your_brain_anees_bahji  12.1M  46.2M  5.17M  2.59M 20191202 6 min 43 s
#                    a_brie_f_history_of_cheese_paul_kindstedt  7.95M  54.1M  7.51M  2.50M 20181213 5 min 33 s
#                     the_infinite_hotel_paradox_jeff_dekofsky  9.92M  64.0M  19.7M  2.46M 20140116 5 min 59 s
#                 can_you_solve_the_bridge_riddle_alex_gendler  6.09M  70.1M  17.0M  2.42M 20150901 3 min 49 s
#                          history_s_worst_nun_theresa_a_yugar  13.6M  83.8M  4.78M  2.39M 20191121 4 min 46 s
#     the_tale_of_the_doctor_who_defied_death_iseult_gillespie  9.68M  93.5M  4.56M  2.28M 20200312 5 min 27 s
#  why_don_t_perpetual_motion_machines_ever_work_netta_schramm  16.6M   110M  11.4M  2.27M 20170605 5 min 30 s
#          can_you_solve_the_wizard_standoff_riddle_dan_finkel  8.15M   118M  8.96M  2.24M 20180522 5 min 25 s
#           questions_no_one_knows_the_answers_to_full_version  34.0M   152M  22.0M  2.20M 20120317 12 min 7 s
# savitri_and_satyavan_the_legend_of_the_princess_who_outwitte  21.3M   173M  2.16M  2.16M 20210112 5 min 40 s
#                            the_language_of_lying_noah_zandan  8.93M   182M  14.9M  2.13M 20141103 5 min 41 s
#                       what_makes_muscles_grow_jeffrey_siegel  6.63M   189M  12.5M  2.09M 20151103 4 min 19 s
#             can_you_solve_the_three_gods_riddle_alex_gendler  7.41M   196M  9.74M  1.95M 20170221 4 min 53 s
#          a_day_in_the_life_of_a_roman_soldier_robert_garland  9.16M   206M  7.78M  1.94M 20180329 4 min 59 s
# how_to_practice_effectively_for_just_about_anything_annie_bo  9.17M   215M  8.88M  1.78M 20170227 4 min 49 s
#   why_incompetent_people_think_they_re_amazing_david_dunning  10.9M   226M  7.09M  1.77M 20171109 5 min 7 s
#                    can_you_solve_the_virus_riddle_lisa_winer  9.66M   235M  8.80M  1.76M 20170403 5 min 12 s
# what_causes_dandruff_and_how_do_you_get_rid_of_it_thomas_l_d  16.3M   252M  1.74M  1.74M 20210209 5 min 4 s
#            can_you_solve_einsteins_riddle_dan_van_der_vieren  8.86M   260M  10.4M  1.73M 20151130 5 min 12 s
# can_you_solve_the_famously_difficult_green_eyed_logic_puzzle  8.05M   268M  11.6M  1.66M 20150616 4 min 41 s
#                    the_myth_of_pandoras_box_iseult_gillespie  10.9M   279M  4.98M  1.66M 20190115 4 min 9 s
#                         the_myth_of_arachne_iseult_gillespie  9.15M   289M  6.60M  1.65M 20180208 4 min 29 s
#         what_would_happen_if_you_didnt_sleep_claudia_aguirre  7.82M   296M  9.77M  1.63M 20151112 4 min 34 s
#     what_would_happen_if_you_didnt_drink_water_mia_nacamulli  8.75M   305M  9.71M  1.62M 20160329 4 min 51 s
# what_really_happened_during_the_salem_witch_trials_brian_a_p  10.1M   315M  3.22M  1.61M 20200504 5 min 30 s
#                        a_brief_history_of_chess_alex_gendler  9.53M   325M  4.71M  1.57M 20190912 5 min 39 s
#             how_do_cigarettes_affect_the_body_krishna_sudhir  12.7M   337M  6.28M  1.57M 20180913 5 min 20 s
# which_is_better_soap_or_hand_sanitizer_alex_rosenthal_and_pa  14.0M   351M  3.13M  1.56M 20200505 6 min 14 s
#                            the_myth_of_sisyphus_alex_gendler  9.76M   361M  4.69M  1.56M 20181113 4 min 56 s
#                   can_you_solve_the_locker_riddle_lisa_winer  6.77M   368M  9.34M  1.56M 20160328 3 min 49 s
#                   how_your_digestive_system_works_emma_bryce  6.85M   375M  6.16M  1.54M 20171214 4 min 56 s
#                 can_you_solve_the_pirate_riddle_alex_gendler  9.00M   384M  7.67M  1.53M 20170501 5 min 23 s
#        how_the_food_you_eat_affects_your_brain_mia_nacamulli  14.6M   398M  8.98M  1.50M 20160621 4 min 52 s
#                  the_myth_of_cupid_and_psyche_brendan_pelsue  16.4M   415M  7.46M  1.49M 20170803 5 min 32 s
#         can_you_solve_the_unstoppable_blob_riddle_dan_finkel  5.70M   421M  4.45M  1.48M 20190318 3 min 42 s
#                  how_does_alcohol_make_you_drunk_judy_grisel  8.19M   429M  2.96M  1.48M 20200409 5 min 25 s
#                                      when_is_a_pandemic_over  15.3M   444M  2.96M  1.48M 20200601 5 min 52 s
#   the_tale_of_the_boy_who_tricked_the_devil_iseult_gillespie  17.9M   462M  2.94M  1.47M 20200707 5 min 25 s
#                      a_brief_history_of_alcohol_rod_phillips  8.92M   471M  2.92M  1.46M 20200102 5 min 20 s
# the_myth_of_thor_s_journey_to_the_land_of_giants_scott_a_mel  7.63M   479M  5.84M  1.46M 20180222 5 min 17 s
#                   the_loathsome_lethal_mosquito_rose_eveleth  4.87M   483M  11.6M  1.45M 20131202 2 min 39 s
#                          why_can_t_you_divide_by_zero_ted_ed  7.70M   491M  5.78M  1.44M 20180423 4 min 50 s
#                     why_do_cats_act_so_weird_tony_buffington  11.9M   503M  8.66M  1.44M 20160426 4 min 57 s
#                      the_myth_of_prometheus_iseult_gillespie  8.23M   511M  5.74M  1.44M 20171114 4 min 46 s
#                        how_does_anesthesia_work_steven_zheng  8.05M   519M  8.48M  1.41M 20151207 4 min 55 s
# who_were_the_vestal_virgins_and_what_was_their_job_peta_gree  12.8M   532M  7.04M  1.41M 20170530 4 min 32 s
#       the_tragic_myth_of_orpheus_and_eurydice_brendan_pelsue  7.92M   540M  5.60M  1.40M 20180111 4 min 41 s
#          can_you_solve_the_prisoner_boxes_riddle_yossi_elran  9.44M   549M  8.40M  1.40M 20161003 4 min 51 s
#        can_you_solve_the_counterfeit_coin_riddle_jennifer_lu  9.45M   559M  6.92M  1.38M 20170103 4 min 34 s
#     the_chinese_myth_of_the_immortal_white_snake_shunan_teng  7.80M   567M  4.14M  1.38M 20190507 4 min 0 s
#                can_you_solve_the_egg_drop_riddle_yossi_elran  8.41M   575M  5.52M  1.38M 20171107 4 min 46 s
#              can_you_solve_the_temple_riddle_dennis_e_shasha  6.70M   582M  8.27M  1.38M 20160201 4 min 12 s
#              the_benefits_of_a_bilingual_brain_mia_nacamulli  11.5M   593M  9.49M  1.36M 20150623 5 min 3 s
#  why_doesnt_the_leaning_tower_of_pisa_fall_over_alex_gendler  9.48M   603M  2.69M  1.34M 20191203 5 min 5 s
#                     how_sugar_affects_the_brain_nicole_avena  16.5M   619M  10.5M  1.31M 20140107 5 min 2 s
#   the_history_of_the_world_according_to_cats_eva_maria_geigl  11.9M   631M  3.93M  1.31M 20190103 4 min 34 s
#       how_does_the_rorschach_inkblot_test_work_damion_searls  12.9M   644M  3.91M  1.30M 20190305 4 min 57 s
# the_myth_of_king_midas_and_his_golden_touch_iseult_gillespie  16.3M   660M  5.18M  1.29M 20180305 5 min 4 s
# mating_frenzies_sperm_hoards_and_brood_raids_the_life_of_a_f  12.0M   672M  2.55M  1.28M 20200116 5 min 18 s
#                 can_you_solve_the_passcode_riddle_ganesh_pai  7.16M   680M  7.62M  1.27M 20160707 4 min 7 s
#                cannibalism_in_the_animal_kingdom_bill_schutt  9.64M   689M  5.06M  1.26M 20180319 4 min 57 s
#                the_psychology_of_narcissism_w_keith_campbell  8.95M   698M  7.58M  1.26M 20160223 5 min 9 s
#              how_does_the_stock_market_work_oliver_elfenbaum  9.18M   707M  3.77M  1.26M 20190429 4 min 29 s
#                            what_is_schizophrenia_anees_bahji  10.5M   718M  2.40M  1.20M 20200326 5 min 32 s
# from_slave_to_rebel_gladiator_the_life_of_spartacus_fiona_ra  19.2M   737M  3.57M  1.19M 20181217 5 min 15 s
#      5_tips_to_improve_your_critical_thinking_samantha_agoos  6.79M   744M  7.13M  1.19M 20160315 4 min 29 s
#       the_rise_and_fall_of_the_berlin_wall_konrad_h_jarausch  9.52M   753M  5.91M  1.18M 20170816 6 min 25 s
#                  the_worlds_most_mysterious_book_stephen_bax  9.37M   763M  5.84M  1.17M 20170525 4 min 42 s
#                           what_is_depression_helen_m_farrell  7.12M   770M  6.99M  1.17M 20151215 4 min 28 s
#                   how_does_a_jellyfish_sting_neosha_s_kashef  7.51M   777M  8.15M  1.16M 20150810 4 min 16 s
# how_did_hitler_rise_to_power_alex_gendler_and_anthony_hazard  11.7M   789M  6.97M  1.16M 20160718 5 min 36 s
#  how_playing_an_instrument_benefits_your_brain_anita_collins  8.59M   798M  9.26M  1.16M 20140722 4 min 44 s
#                 the_benefits_of_good_posture_murat_dalkilinc  5.78M   803M  8.08M  1.15M 20150730 4 min 26 s
#                          are_the_illuminati_real_chip_berlet  7.43M   811M  2.30M  1.15M 20191031 4 min 57 s
#                       does_time_exist_andrew_zimmerman_jones  15.1M   826M  4.57M  1.14M 20181023 5 min 15 s
#                   how_to_spot_a_pyramid_scheme_stacie_bosley  7.23M   833M  3.41M  1.14M 20190402 5 min 1 s
#                   the_myth_of_icarus_and_daedalus_amy_adkins  15.2M   848M  5.62M  1.12M 20170313 5 min 8 s
# a_day_in_the_life_of_an_ancient_egyptian_doctor_elizabeth_co  7.03M   855M  4.48M  1.12M 20180719 4 min 33 s
# the_myth_behind_the_chinese_zodiac_megan_campisi_and_pen_pen  6.53M   862M  5.60M  1.12M 20170126 4 min 22 s
# what_happens_to_our_bodies_after_we_die_farnaz_khatibi_jafar  8.41M   870M  6.72M  1.12M 20161013 4 min 40 s
#        the_myth_of_hercules_12_labors_in_8_bits_alex_gendler  23.8M   894M  4.48M  1.12M 20180925 7 min 50 s
#                   can_you_solve_the_frog_riddle_derek_abbott  6.91M   901M  6.71M  1.12M 20160229 4 min 30 s
#                 the_philosophy_of_stoicism_massimo_pigliucci  10.3M   911M  5.58M  1.12M 20170619 5 min 29 s
# the_atlantic_slave_trade_what_too_few_textbooks_told_you_ant  10.8M   922M  7.70M  1.10M 20141222 5 min 38 s
#                        historys_deadliest_colors_j_v_maranto  14.5M   937M  5.48M  1.10M 20170522 5 min 13 s
#                          the_surprising_effects_of_pregnancy  19.8M   957M  2.18M  1.09M 20201001 5 min 45 s
#                 can_you_solve_the_ragnarok_riddle_dan_finkel  22.4M   979M  2.14M  1.07M 20200630 5 min 14 s
# the_legend_of_annapurna_hindu_goddess_of_nourishment_antara_  8.40M   987M  2.13M  1.06M 20200213 5 min 8 s
#           can_you_solve_the_river_crossing_riddle_lisa_winer  8.29M   996M  5.30M  1.06M 20161101 4 min 18 s
#                  the_history_of_chocolate_deanna_pucciarelli  8.67M  0.98G  5.25M  1.05M 20170316 4 min 40 s
#                       the_bug_that_poops_candy_george_zaidan  14.1M  0.99G  2.09M  1.04M 20200414 4 min 46 s
#   the_surprising_reason_our_muscles_get_tired_christian_moro  10.6M  1.00G  3.12M  1.04M 20190418 4 min 24 s
#              can_you_solve_the_airplane_riddle_judd_a_schorr  9.30M  1.01G  5.18M  1.04M 20161201 4 min 37 s
#       a_glimpse_of_teenage_life_in_ancient_rome_ray_laurence  15.9M  1.03G  10.2M  1.02M 20121029 6 min 34 s
#                how_does_laser_eye_surgery_work_dan_reinstein  12.1M  1.04G  2.04M  1.02M 20191119 5 min 36 s
#                      the_dark_history_of_bananas_john_soluri  17.6M  1.06G  1.01M  1.01M 20201102 6 min 2 s
#              why_are_some_people_left_handed_daniel_m_abrams  8.22M  1.07G  7.02M  1.00M 20150203 5 min 6 s
#     can_you_solve_the_penniless_pilgrim_riddle_daniel_finkel  6.60M  1.07G  3.97M  0.99M 20180604 4 min 44 s
#                                    why_do_we_itch_emma_bryce  13.6M  1.09G  4.92M  0.98M 20170411 4 min 43 s
#                  what_makes_something_kafkaesque_noah_tavlin  19.7M  1.11G  5.87M  0.98M 20160620 5 min 3 s
#    the_three_different_ways_mammals_give_birth_kate_slabosky  8.55M  1.11G  4.88M  0.98M 20170417 4 min 49 s
#                       3_tips_to_boost_your_confidence_ted_ed  9.28M  1.12G  6.83M   999K 20151006 4 min 16 s
# the_unexpected_math_behind_van_gogh_s_starry_night_natalya_s  14.7M  1.14G  7.79M   997K 20141030 4 min 38 s
#               einstein_s_twin_paradox_explained_amber_stuver  11.7M  1.15G  2.91M   993K 20190926 6 min 15 s
#                 can_you_solve_the_fish_riddle_steve_wyborney  8.49M  1.16G  4.81M   986K 20170626 4 min 49 s
# how_to_manage_your_time_more_effectively_according_to_machin  7.65M  1.16G  3.81M   976K 20180102 5 min 9 s
#                            history_vs_cleopatra_alex_gendler  7.53M  1.17G  4.74M   972K 20170202 4 min 27 s
# the_egyptian_book_of_the_dead_a_guidebook_for_the_underworld  7.39M  1.18G  4.74M   971K 20161031 4 min 31 s
#                the_five_major_world_religions_john_bellaimey  36.6M  1.21G  7.56M   968K 20131114 11 min 9 s
#                            how_do_tornadoes_form_james_spann  8.52M  1.22G  7.43M   951K 20140819 4 min 11 s
#                   a_brief_history_of_cannibalism_bill_schutt  8.18M  1.23G  2.76M   942K 20190725 4 min 49 s
#         the_mysterious_life_and_death_of_rasputin_eden_girma  8.68M  1.24G  1.84M   941K 20200107 5 min 13 s
# how_to_stay_calm_under_pressure_noa_kageyama_and_pen_pen_che  8.06M  1.25G  3.63M   929K 20180521 4 min 28 s
#                    four_sisters_in_ancient_rome_ray_laurence  17.2M  1.26G  8.15M   928K 20130514 8 min 38 s
#                whats_that_ringing_in_your_ears_marc_fagelson  22.4M  1.29G  1.80M   923K 20200817 5 min 38 s
#    the_rise_and_fall_of_the_byzantine_empire_leonora_neville  8.15M  1.29G  3.60M   922K 20180409 5 min 20 s
#            what_happens_during_a_heart_attack_krishna_sudhir  8.09M  1.30G  4.50M   921K 20170214 4 min 53 s
#   the_myth_of_loki_and_the_deadly_mistletoe_iseult_gillespie  22.2M  1.32G   914K   914K 20201201 5 min 28 s
#                                   why_do_we_dream_amy_adkins  13.5M  1.34G  5.35M   914K 20151210 5 min 37 s
#                                    why_do_women_have_periods  7.05M  1.34G  6.23M   911K 20151019 4 min 45 s
#       why_should_you_read_dune_by_frank_herbert_dan_kwartler  12.1M  1.36G  1.78M   910K 20191217 5 min 5 s
#                   why_sitting_is_bad_for_you_murat_dalkilinc  8.20M  1.36G  6.10M   892K 20150305 5 min 4 s
# licking_bees_and_pulping_trees_the_reign_of_a_wasp_queen_ken  10.9M  1.37G  1.73M   885K 20200128 5 min 22 s
#                          history_vs_che_guevara_alex_gendler  11.8M  1.39G  3.45M   884K 20171127 6 min 7 s
#    the_rise_and_fall_of_the_mongol_empire_anne_f_broadbridge  12.1M  1.40G  2.54M   865K 20190829 5 min 0 s
#                how_does_money_laundering_work_delena_d_spann  11.9M  1.41G  4.20M   860K 20170523 4 min 46 s
#   the_great_conspiracy_against_julius_caesar_kathryn_tempest  10.4M  1.42G  5.86M   858K 20141218 5 min 57 s
# mansa_musa_one_of_the_wealthiest_people_who_ever_lived_jessi  12.4M  1.43G  5.83M   853K 20150518 3 min 54 s
#           can_you_solve_the_monster_duel_riddle_alex_gendler  16.3M  1.45G   841K   841K 20201208 5 min 35 s
#                               how_tsunamis_work_alex_gendler  8.95M  1.46G  6.55M   838K 20140424 3 min 36 s
#                               the_history_of_tea_shunan_teng  7.57M  1.46G  4.09M   837K 20170516 4 min 57 s
# why_do_we_like_hesitate_when_we_um_speak_lorenzo_garcia_amay  19.0M  1.48G   835K   835K 20210218 5 min 33 s
# why_do_animals_have_such_different_lifespans_joao_pedro_de_m  7.36M  1.49G  4.06M   831K 20170404 4 min 56 s
#                          why_are_sloths_so_slow_kenny_coogan  7.71M  1.50G  4.02M   824K 20170425 5 min 14 s
#        can_you_solve_the_dragon_jousting_riddle_alex_gendler  9.13M  1.51G  1.61M   823K 20200109 5 min 3 s
#                       how_does_asthma_work_christopher_e_gaw  8.91M  1.51G  3.99M   817K 20170511 5 min 9 s
# which_type_of_milk_is_best_for_you_jonathan_j_osullivan_grac  19.1M  1.53G  1.59M   813K 20201020 5 min 25 s
# the_cambodian_myth_of_lightning_thunder_and_rain_prumsodun_o  11.6M  1.54G  3.17M   811K 20180410 4 min 37 s
# why_isn_t_the_world_covered_in_poop_eleanor_slade_and_paul_m  7.34M  1.55G  3.16M   809K 20180326 4 min 57 s
#               can_you_solve_the_jail_break_riddle_dan_finkel  7.25M  1.56G  2.35M   802K 20190226 3 min 24 s
#                            what_makes_a_hero_matthew_winkler  11.4M  1.57G  7.04M   802K 20121204 4 min 33 s
#             can_you_solve_the_cheating_royal_riddle_dan_katz  19.3M  1.59G  1.56M   799K 20200811 5 min 48 s
#          can_you_solve_the_control_room_riddle_dennis_shasha  6.73M  1.59G  4.65M   793K 20160531 4 min 0 s
# meet_the_tardigrade_the_toughest_animal_on_earth_thomas_boot  7.11M  1.60G  3.87M   793K 20170321 4 min 9 s
#                           what_causes_headaches_dan_kwartler  9.18M  1.61G  3.09M   791K 20180412 5 min 31 s
#                can_you_solve_the_dark_coin_riddle_lisa_winer  9.85M  1.62G  3.08M   788K 20180122 5 min 25 s
#    can_you_solve_the_multiplying_rabbits_riddle_alex_gendler  7.66M  1.63G  2.31M   788K 20190110 4 min 38 s
#         can_you_solve_the_seven_planets_riddle_edwin_f_meyer  9.29M  1.64G  3.07M   785K 20180226 6 min 0 s
#                       where_does_gold_come_from_david_lunney  9.66M  1.65G  5.34M   781K 20151008 4 min 34 s
#          can_you_solve_the_secret_werewolf_riddle_dan_finkel  7.43M  1.65G  2.28M   779K 20181108 4 min 28 s
#                  why_the_metric_system_matters_matt_anticole  7.17M  1.66G  4.55M   776K 20160721 5 min 7 s
# how_the_world_s_longest_underwater_tunnel_was_built_alex_gen  9.61M  1.67G  1.51M   775K 20200330 5 min 37 s
#   can_you_solve_the_leonardo_da_vinci_riddle_tanya_khovanova  7.97M  1.68G  3.00M   768K 20180823 5 min 7 s
#                        why_do_people_join_cults_janja_lalich  12.4M  1.69G  3.73M   765K 20170612 6 min 26 s
#     the_greatest_mathematician_that_never_lived_pratik_aghor  16.1M  1.71G  1.48M   757K 20200706 5 min 12 s
#   would_you_sacrifice_one_person_to_save_five_eleanor_nelsen  7.06M  1.71G  3.67M   751K 20170112 4 min 55 s
#          the_wars_that_inspired_game_of_thrones_alex_gendler  11.0M  1.72G  5.11M   748K 20150511 6 min 0 s
#    can_you_solve_the_alice_in_wonderland_riddle_alex_gendler  16.9M  1.74G   747K   747K 20201117 5 min 4 s
#              can_you_solve_the_sea_monster_riddle_dan_finkel  12.4M  1.75G  1.46M   747K 20200402 5 min 27 s
#                      what_causes_kidney_stones_arash_shadman  6.68M  1.76G  3.64M   746K 20170703 5 min 14 s
#         hawking_s_black_hole_paradox_explained_fabio_pacucci  11.2M  1.77G  2.18M   745K 20191022 5 min 37 s
#          why_do_we_cry_the_three_types_of_tears_alex_gendler  7.77M  1.78G  5.81M   744K 20140226 3 min 58 s
# why_should_you_read_lord_of_the_flies_by_william_golding_jil  12.0M  1.79G  1.45M   742K 20191212 4 min 47 s
#                        how_do_solar_panels_work_richard_komp  7.14M  1.80G  4.34M   740K 20160105 4 min 58 s
# does_your_vote_count_the_electoral_college_explained_christi  11.1M  1.81G  6.50M   739K 20121101 5 min 21 s
#                     what_is_bipolar_disorder_helen_m_farrell  8.08M  1.81G  3.58M   734K 20170209 5 min 57 s
#        the_egyptian_myth_of_the_death_of_osiris_alex_gendler  20.5M  1.83G  1.43M   733K 20200716 4 min 14 s
# what_would_happen_if_every_human_suddenly_disappeared_dan_kw  9.30M  1.84G  2.85M   730K 20180917 5 min 21 s
# what_is_imposter_syndrome_and_how_can_you_combat_it_elizabet  6.54M  1.85G  2.85M   729K 20180828 4 min 18 s
#   why_the_octopus_brain_is_so_extraordinary_claudio_l_guerra  7.17M  1.86G  4.26M   727K 20151203 4 min 16 s
#                why_isnt_the_netherlands_underwater_stefan_al  10.3M  1.87G  1.42M   725K 20200324 5 min 23 s
# how_do_steroids_affect_your_muscles_and_the_rest_of_your_bod  18.1M  1.88G   724K   724K 20201109 5 min 48 s
#        history_through_the_eyes_of_a_chicken_chris_a_kniesly  14.1M  1.90G  2.82M   722K 20181011 5 min 11 s
#         can_you_solve_the_false_positive_riddle_alex_gendler  10.4M  1.91G  2.82M   721K 20180508 5 min 19 s
# the_egyptian_myth_of_isis_and_the_seven_scorpions_alex_gendl  8.66M  1.92G  1.41M   720K 20200302 3 min 34 s
#             ancient_romes_most_notorious_doctor_ramon_glazov  8.17M  1.92G  2.10M   718K 20190718 5 min 10 s
# mary_s_room_a_philosophical_thought_experiment_eleanor_nelse  6.90M  1.93G  3.50M   717K 20170124 4 min 51 s
#                 the_philosophy_of_cynicism_william_d_desmond  10.2M  1.94G  1.40M   717K 20191219 5 min 25 s
#                         history_vs_genghis_khan_alex_gendler  10.4M  1.95G  4.87M   713K 20150702 6 min 6 s
#               how_stress_affects_your_brain_madhumita_murgia  7.50M  1.96G  4.17M   712K 20151109 4 min 15 s
#           no_one_can_figure_out_how_eels_have_sex_lucy_cooke  22.0M  1.98G  1.38M   708K 20200727 6 min 1 s
#              can_you_solve_the_time_travel_riddle_dan_finkel  8.14M  1.99G  2.07M   708K 20181204 4 min 31 s
#                                 the_myth_of_the_boiling_frog  14.5M  2.00G   707K   707K 20210216 4 min 40 s
# the_worlds_most_dangerous_fart_nick_caruso_and_dani_rabaiott  14.4M  2.02G   706K   706K 20210201 4 min 42 s
#           can_you_outsmart_this_logical_fallacy_alex_gendler  6.02M  2.02G  1.37M   701K 20191125 3 min 44 s
# the_dark_ages_how_dark_were_they_really_crash_course_world_h  29.8M  2.05G  6.82M   699K 20120426 12 min 7 s
#   why_should_you_read_tolstoy_s_war_and_peace_brendan_pelsue  10.4M  2.06G  3.40M   697K 20170427 5 min 9 s
#                 can_you_solve_the_rogue_ai_riddle_dan_finkel  9.02M  2.07G  2.72M   697K 20180807 5 min 12 s
#                  how_to_build_a_fictional_world_kate_messner  10.1M  2.08G  5.44M   696K 20140109 5 min 24 s
#         the_myth_of_loki_and_the_master_builder_alex_gendler  7.81M  2.09G  1.35M   692K 20191114 4 min 37 s
#                      how_do_pregnancy_tests_work_tien_nguyen  8.90M  2.10G  4.73M   692K 20150707 4 min 33 s
# schrodinger_s_cat_a_thought_experiment_in_quantum_mechanics_  6.93M  2.10G  5.40M   691K 20141014 4 min 37 s
#             cell_vs_virus_a_battle_for_health_shannon_stiles  10.1M  2.11G  5.39M   690K 20140417 3 min 58 s
#          the_fascinating_history_of_cemeteries_keith_eggener  9.83M  2.12G  2.68M   687K 20181030 5 min 18 s
#      a_day_in_the_life_of_an_ancient_athenian_robert_garland  10.1M  2.13G  2.66M   681K 20180315 5 min 1 s
# what_if_there_were_1_trillion_more_trees_jean_francois_basti  24.6M  2.16G  1.32M   677K 20201027 5 min 43 s
#                     platos_allegory_of_the_cave_alex_gendler  13.0M  2.17G  4.62M   675K 20150317 4 min 32 s
#           how_to_outsmart_the_prisoners_dilemma_lucas_husted  22.9M  2.19G  1.31M   671K 20200827 5 min 44 s
# what_makes_the_great_wall_of_china_so_extraordinary_megan_ca  6.95M  2.20G  4.55M   666K 20150917 4 min 29 s
#          why_should_you_read_fahrenheit_451_iseult_gillespie  9.36M  2.21G  1.95M   664K 20190122 4 min 35 s
#                 how_does_chemotherapy_work_hyunsoo_joshua_no  12.9M  2.22G  1.30M   664K 20191205 5 min 25 s
#           can_you_solve_the_vampire_hunter_riddle_dan_finkel  5.88M  2.23G  1.95M   664K 20190128 3 min 51 s
#           can_you_solve_the_trolls_paradox_riddle_dan_finkel  10.2M  2.24G  1.94M   663K 20181220 3 min 44 s
#         why_do_we_love_a_philosophical_inquiry_skye_c_cleary  9.31M  2.25G  3.88M   663K 20160211 5 min 44 s
#                       a_brief_history_of_dogs_david_ian_howe  9.68M  2.25G  1.94M   662K 20190326 4 min 58 s
#      how_we_conquered_the_deadly_smallpox_virus_simona_zompi  9.12M  2.26G  5.78M   658K 20131028 4 min 33 s
# can_you_solve_the_cuddly_duddly_fuddly_wuddly_riddle_dan_fin  6.06M  2.27G  1.92M   654K 20190425 3 min 34 s
#                 the_life_cycle_of_a_cup_of_coffee_a_j_jacobs  20.9M  2.29G   652K   652K 20210104 5 min 4 s
#                  how_does_your_immune_system_work_emma_bryce  9.65M  2.30G  2.52M   646K 20180108 5 min 22 s
#                        the_science_of_attraction_dawn_maslar  6.78M  2.31G  5.05M   646K 20140508 4 min 33 s
#       the_greek_myth_of_talos_the_first_robot_adrienne_mayor  8.36M  2.31G  1.89M   645K 20191024 4 min 6 s
# what_s_the_difference_between_accuracy_and_precision_matt_an  7.40M  2.32G  4.39M   642K 20150414 4 min 52 s
#                8_traits_of_successful_people_richard_st_john  19.1M  2.34G  5.61M   638K 20130405 7 min 17 s
#                   history_vs_napoleon_bonaparte_alex_gendler  8.85M  2.35G  3.73M   637K 20160204 5 min 21 s
#         what_yoga_does_to_your_body_and_brain_krishna_sudhir  19.4M  2.37G  1.24M   637K 20200618 6 min 1 s
# this_tool_will_help_improve_your_critical_thinking_erick_wil  15.6M  2.38G   636K   636K 20210412 5 min 19 s
#  can_you_solve_the_worlds_most_evil_wizard_riddle_dan_finkel  8.54M  2.39G  1.24M   635K 20200519 5 min 16 s
#                    the_dangers_of_mixing_drugs_celine_valery  14.3M  2.41G  1.23M   630K 20191112 5 min 3 s
# everything_changed_when_the_fire_crystal_got_stolen_alex_gen  9.03M  2.41G  1.23M   629K 20200206 4 min 21 s
#                          what_is_a_coronavirus_elizabeth_cox  8.85M  2.42G  1.23M   629K 20200514 5 min 15 s
#                 where_do_superstitions_come_from_stuart_vyse  8.38M  2.43G  3.07M   628K 20170309 5 min 10 s
#         can_you_solve_the_stolen_rubies_riddle_dennis_shasha  10.1M  2.44G  2.45M   628K 20181025 4 min 50 s
#       how_do_carbohydrates_impact_your_health_richard_j_wood  8.69M  2.45G  3.68M   628K 20160111 5 min 10 s
#         how_the_food_you_eat_affects_your_gut_shilpa_ravella  12.3M  2.46G  3.06M   628K 20170323 5 min 9 s
#             can_you_solve_the_giant_iron_riddle_alex_gendler  5.39M  2.47G  1.83M   625K 20181127 3 min 37 s
#                       how_a_wound_heals_itself_sarthak_sinha  7.79M  2.47G  4.26M   623K 20141110 4 min 0 s
#                  why_is_it_so_hard_to_cure_cancer_kyuson_yun  14.5M  2.49G  3.04M   622K 20171010 5 min 22 s
#             the_dark_history_of_iq_tests_stefan_c_dombrowski  12.8M  2.50G  1.21M   621K 20200427 6 min 9 s
#                      why_elephants_never_forget_alex_gendler  8.72M  2.51G  4.24M   620K 20141113 5 min 22 s
#                                    just_how_small_is_an_atom  14.7M  2.52G  6.05M   620K 20120416 5 min 27 s
#    how_much_of_what_you_see_is_a_hallucination_elizabeth_cox  12.7M  2.54G  2.42M   619K 20180626 5 min 49 s
# why_is_vermeer_s_girl_with_the_pearl_earring_considered_a_ma  8.37M  2.54G  3.62M   618K 20161018 4 min 33 s
#                  why_is_cotton_in_everything_michael_r_stiff  10.4M  2.55G  1.20M   616K 20200123 4 min 53 s
# is_life_meaningless_and_other_absurd_questions_nina_medvinsk  18.8M  2.57G  1.20M   614K 20200921 6 min 12 s
#                     how_to_recognize_a_dystopia_alex_gendler  20.0M  2.59G  2.99M   613K 20161115 5 min 55 s
# zen_koans_unsolvable_enigmas_designed_to_break_your_brain_pu  14.2M  2.61G  2.39M   613K 20180816 4 min 57 s
#                 debunking_the_myths_of_ocd_natascha_m_santos  9.04M  2.62G  4.18M   611K 20150519 4 min 50 s
#                  how_does_caffeine_keep_us_awake_hanan_qasim  8.05M  2.62G  2.97M   609K 20170717 5 min 14 s
#                           what_causes_cavities_mel_rosenberg  9.96M  2.63G  3.57M   609K 20161017 5 min 0 s
#              the_greatest_ted_talk_ever_sold_morgan_spurlock  38.9M  2.67G  5.34M   608K 20130315 19 min 28 s
#          will_there_ever_be_a_mile_high_skyscraper_stefan_al  9.17M  2.68G  1.78M   607K 20190207 5 min 4 s
#                 what_makes_tattoos_permanent_claudia_aguirre  8.82M  2.69G  4.71M   603K 20140710 4 min 25 s
# what_s_the_fastest_way_to_alphabetize_your_bookshelf_chand_j  6.22M  2.69G  2.94M   603K 20161128 4 min 38 s
#                         how_do_ventilators_work_alex_gendler  12.1M  2.71G  1.18M   602K 20200521 5 min 41 s
#                      where_did_russia_come_from_alex_gendler  13.9M  2.72G  4.11M   602K 20151013 5 min 19 s
#                  how_do_fish_make_electricity_eleanor_nelsen  10.4M  2.73G  2.35M   601K 20171130 5 min 14 s
#           the_rise_and_fall_of_the_inca_empire_gordon_mcewan  14.5M  2.74G  2.34M   600K 20180212 5 min 45 s
#                 why_do_humans_have_a_third_eyelid_dorsa_amir  8.01M  2.75G  1.17M   599K 20191111 4 min 35 s
#           can_you_solve_the_secret_sauce_riddle_alex_gendler  7.29M  2.76G  1.75M   598K 20190916 4 min 42 s
#           can_you_solve_the_giant_cat_army_riddle_dan_finkel  9.01M  2.77G  2.33M   597K 20180611 5 min 19 s
#   the_history_of_the_world_according_to_corn_chris_a_kniesly  14.0M  2.78G  1.16M   594K 20191126 5 min 22 s
# why_didnt_this_2000_year_old_body_decompose_carolyn_marshall  19.0M  2.80G   590K   590K 20210204 4 min 59 s
#        why_should_you_read_crime_and_punishment_alex_gendler  8.22M  2.81G  1.73M   589K 20190514 4 min 45 s
#         how_stress_affects_your_body_sharon_horesh_bergquist  8.32M  2.82G  4.02M   588K 20151022 4 min 42 s
# why_should_you_read_one_hundred_years_of_solitude_francisco_  14.1M  2.83G  2.30M   588K 20180830 5 min 30 s
#            should_you_trust_unanimous_decisions_derek_abbott  6.56M  2.84G  3.44M   587K 20160418 4 min 2 s
#                            what_causes_insomnia_dan_kwartler  7.39M  2.84G  2.29M   586K 20180614 5 min 11 s
#     the_history_of_the_cuban_missile_crisis_matthew_a_jordan  9.69M  2.85G  3.43M   585K 20160926 4 min 51 s
#            the_chinese_myth_of_the_meddling_monk_shunan_teng  8.00M  2.86G  1.71M   584K 20190523 4 min 3 s
#                                what_is_entropy_jeff_phillips  7.75M  2.87G  2.85M   584K 20170509 5 min 19 s
#          the_immortal_cells_of_henrietta_lacks_robin_bulleri  9.48M  2.88G  3.41M   583K 20160208 4 min 26 s
#                 how_do_animals_experience_pain_robyn_j_crook  7.80M  2.89G  2.84M   582K 20170117 5 min 6 s
#               who_decides_how_long_a_second_is_john_kitching  20.8M  2.91G   582K   582K 20210119 5 min 46 s
#      can_you_solve_the_buried_treasure_riddle_daniel_griller  9.47M  2.91G  2.26M   579K 20180322 5 min 2 s
#                     why_are_there_so_many_insects_murry_gans  7.45M  2.92G  3.36M   573K 20160301 4 min 43 s
#                     why_bats_don_t_get_sick_arinjay_banerjee  24.8M  2.95G   570K   570K 20210126 5 min 49 s
#                   why_should_you_read_macbeth_brendan_pelsue  10.5M  2.96G  2.21M   566K 20171102 6 min 8 s
#                        platos_best_and_worst_ideas_wisecrack  9.76M  2.97G  3.26M   557K 20161025 4 min 48 s
#                      is_it_bad_to_hold_your_pee_heba_shaheed  6.40M  2.97G  3.25M   555K 20161010 3 min 58 s
#                      why_do_your_knuckles_pop_eleanor_nelsen  12.1M  2.98G  3.77M   551K 20150505 4 min 21 s
#           the_most_successful_pirate_of_all_time_dian_murray  8.43M  2.99G  2.15M   550K 20180402 5 min 16 s
# how_did_dracula_become_the_world_s_most_famous_vampire_stanl  10.5M  3.00G  2.68M   550K 20170420 5 min 5 s
# how_high_can_you_count_on_your_fingers_spoiler_much_higher_t  9.61M  3.01G  2.66M   545K 20161215 4 min 29 s
# why_should_you_listen_to_vivaldi_s_four_seasons_betsy_schwar  8.74M  3.02G  3.18M   543K 20161024 4 min 19 s
# can_you_solve_the_sorting_hat_riddle_dan_katz_and_alex_rosen  20.2M  3.04G  1.06M   542K 20200901 5 min 59 s
#                          what_causes_body_odor_mel_rosenberg  6.32M  3.05G  2.12M   542K 20180405 4 min 28 s
#                 if_superpowers_were_real_immortality_joy_lin  14.3M  3.06G  4.76M   541K 20130627 4 min 29 s
#              the_benefits_of_a_good_night_s_sleep_shai_marcu  11.3M  3.07G  3.70M   541K 20150105 5 min 44 s
#                    at_what_moment_are_you_dead_randall_hayes  9.25M  3.08G  3.69M   539K 20141211 5 min 33 s
#                    where_did_english_come_from_claire_bowern  9.49M  3.09G  3.67M   537K 20150716 4 min 53 s
# the_journey_to_pluto_the_farthest_world_ever_explored_alan_s  8.63M  3.10G  2.10M   536K 20180517 6 min 9 s
#                  did_the_amazons_really_exist_adrienne_mayor  14.0M  3.11G  2.09M   535K 20180618 5 min 5 s
#                       the_sonic_boom_problem_katerina_kaouri  11.3M  3.12G  3.65M   534K 20150210 5 min 43 s
#                         do_personality_tests_work_merve_emre  19.5M  3.14G   534K   534K 20201222 4 min 56 s
#                     how_blood_pressure_works_wilfred_manzano  8.16M  3.15G  3.65M   534K 20150723 4 min 31 s
#              is_fire_a_solid_a_liquid_or_a_gas_elizabeth_cox  9.93M  3.16G  1.56M   534K 20181105 4 min 34 s
#            the_art_forger_who_tricked_the_nazis_noah_charney  10.4M  3.17G  1.04M   530K 20200406 5 min 16 s
#          how_squids_outsmart_their_predators_carly_anne_york  9.54M  3.18G  2.05M   526K 20180514 5 min 12 s
#                    how_to_write_descriptively_nalo_hopkinson  12.1M  3.19G  3.08M   525K 20151116 4 min 41 s
#        the_treadmill_s_dark_and_twisted_past_conor_heffernan  14.6M  3.21G  3.59M   525K 20150922 4 min 9 s
#                                how_to_make_a_mummy_len_bloch  7.41M  3.21G  3.57M   522K 20150618 4 min 45 s
#                           a_brief_history_of_goths_dan_adams  11.8M  3.22G  2.54M   521K 20170518 5 min 30 s
#    the_material_that_could_change_the_world_for_a_third_time  15.2M  3.24G   521K   521K 20210301 5 min 26 s
#                                   string_theory_brian_greene  37.8M  3.28G  4.57M   520K 20130809 19 min 9 s
#    the_rise_and_fall_of_the_assyrian_empire_marian_h_feldman  12.1M  3.29G  2.03M   520K 20180424 5 min 15 s
#  the_amazing_ways_plants_defend_themselves_valentin_hammoudi  11.5M  3.30G  2.53M   519K 20170828 6 min 11 s
#                        your_body_vs_implants_kaitlyn_sadtler  11.4M  3.31G  1.52M   518K 20190617 4 min 39 s
#             can_you_solve_the_death_race_riddle_alex_gendler  13.6M  3.32G  1.01M   517K 20200303 5 min 50 s
# is_human_evolution_speeding_up_or_slowing_down_laurence_hurs  21.1M  3.34G  1.01M   516K 20200922 5 min 47 s
#                       history_vs_sigmund_freud_todd_dufresne  8.79M  3.35G  1.00M   512K 20200331 5 min 54 s
# what_causes_opioid_addiction_and_why_is_it_so_tough_to_comba  19.1M  3.37G  1.00M   511K 20200507 8 min 21 s
# the_myth_of_oisin_and_the_land_of_eternal_youth_iseult_gille  8.19M  3.38G  1.99M   510K 20180118 3 min 49 s
#     how_parasites_change_their_host_s_behavior_jaap_de_roode  10.1M  3.39G  3.48M   510K 20150309 5 min 13 s
#       how_the_monkey_king_escaped_the_underworld_shunan_teng  15.4M  3.40G  0.99M   509K 20200407 4 min 57 s
#            the_pharaoh_that_wouldn_t_be_forgotten_kate_green  9.09M  3.41G  3.48M   509K 20141215 4 min 33 s
#                      the_genius_of_marie_curie_shohini_ghose  9.06M  3.42G  2.48M   509K 20170608 5 min 3 s
# what_really_happens_to_the_plastic_you_throw_away_emma_bryce  6.68M  3.43G  3.47M   507K 20150421 4 min 6 s
#                how_fast_is_the_speed_of_thought_seena_mathew  20.8M  3.45G   507K   507K 20201116 5 min 16 s
#       what_is_the_tragedy_of_the_commons_nicholas_amendolare  12.4M  3.46G  1.98M   506K 20171121 4 min 57 s
#                       history_vs_vladimir_lenin_alex_gendler  15.9M  3.48G  3.92M   502K 20140407 6 min 42 s
#                                 how_to_read_music_tim_hansen  8.54M  3.48G  4.40M   501K 20130718 5 min 23 s
# debunking_the_myth_of_the_lost_cause_a_lie_embedded_in_ameri  15.7M  3.50G   499K   499K 20210225 4 min 42 s
#                          how_to_unboil_an_egg_eleanor_nelsen  7.29M  3.51G  3.40M   498K 20150423 4 min 9 s
#  how_the_normans_changed_the_history_of_europe_mark_robinson  13.3M  3.52G  1.94M   498K 20180809 5 min 19 s
#    a_day_in_the_life_of_a_mongolian_queen_anne_f_broadbridge  7.17M  3.53G  1.46M   497K 20190117 4 min 23 s
# game_theory_challenge_can_you_predict_human_behavior_lucas_h  5.95M  3.53G   992K   496K 20191105 4 min 58 s
#            how_does_your_body_process_medicine_celine_valery  9.04M  3.54G  2.42M   496K 20170515 4 min 12 s
#           the_scientific_origins_of_the_minotaur_matt_kaplan  10.4M  3.55G  3.38M   495K 20150720 4 min 40 s
# ethical_dilemma_the_burger_murders_george_siedel_and_christi  21.9M  3.57G   989K   494K 20200728 5 min 45 s
#                   the_power_of_the_placebo_effect_emma_bryce  8.45M  3.58G  2.89M   493K 20160404 4 min 37 s
# why_dont_poisonous_animals_poison_themselves_rebecca_d_tarvi  9.25M  3.59G  1.91M   488K 20180705 5 min 9 s
#      the_real_story_behind_archimedes_eureka_armand_d_angour  10.3M  3.60G  3.33M   488K 20150313 4 min 41 s
# exponential_growth_how_folding_paper_can_get_you_to_the_moon  6.30M  3.61G  4.76M   487K 20120419 3 min 48 s
# this_is_sparta_fierce_warriors_of_the_ancient_world_craig_zi  8.43M  3.61G  2.82M   482K 20160308 4 min 27 s
#      what_is_the_heisenberg_uncertainty_principle_chad_orzel  5.96M  3.62G  3.76M   481K 20140916 4 min 43 s
#                why_is_meningitis_so_dangerous_melvin_sanicas  9.77M  3.63G  1.41M   481K 20181119 4 min 53 s
# titan_of_terror_the_dark_imagination_of_h_p_lovecraft_silvia  8.52M  3.64G  1.39M   476K 20190423 4 min 46 s
#            can_loud_music_damage_your_hearing_heather_malyuk  20.7M  3.66G   475K   475K 20210302 5 min 9 s
# what_machiavellian_really_means_pazit_cahlon_and_alex_gendle  7.85M  3.67G  1.39M   474K 20190325 5 min 9 s
#                whatever_happened_to_acid_rain_joseph_goffman  19.6M  3.69G   474K   474K 20210413 5 min 39 s
#       why_doesnt_anything_stick_to_teflon_ashwini_bharathula  8.67M  3.69G  2.30M   472K 20161213 4 min 44 s
#                     how_do_vitamins_work_ginnie_trinh_nguyen  9.07M  3.70G  3.68M   471K 20141006 4 min 43 s
#                      ugly_history_witch_hunts_brian_a_pavlac  13.9M  3.72G  1.38M   471K 20190611 5 min 25 s
# why_do_competitors_open_their_stores_next_to_one_another_jac  8.49M  3.72G  4.59M   470K 20121001 4 min 6 s
#                        what_is_dyslexia_kelli_sandman_hurley  7.51M  3.73G  4.13M   470K 20130715 4 min 34 s
#         the_evolution_of_animal_genitalia_menno_schilthuizen  13.2M  3.74G  2.29M   469K 20170424 5 min 35 s
#                               is_telekinesis_real_emma_bryce  8.68M  3.75G  3.66M   469K 20140930 5 min 22 s
# the_incredible_history_of_china_s_terracotta_warriors_megan_  7.41M  3.76G  3.20M   468K 20150630 4 min 31 s
#                  how_fast_can_a_vaccine_be_made_dan_kwartler  20.4M  3.78G   933K   466K 20200615 5 min 51 s
#                these_squids_can_fly_no_really_robert_siddall  20.1M  3.80G   466K   466K 20210111 4 min 56 s
# which_bag_should_you_use_luka_seamus_wright_and_imogen_ellen  14.6M  3.81G   461K   461K 20201119 4 min 52 s
#         can_you_solve_the_rebel_supplies_riddle_alex_gendler  8.80M  3.82G  1.80M   461K 20180910 5 min 17 s
#    the_aztec_myth_of_the_unlikeliest_sun_god_kay_almere_read  12.1M  3.83G  1.34M   456K 20190509 4 min 12 s
# dna_hot_pockets_the_longest_word_ever_crash_course_biology_1  44.7M  3.88G  4.43M   453K 20120409 14 min 7 s
# a_day_in_the_life_of_an_ancient_babylonian_business_mogul_so  22.4M  3.90G   452K   452K 20210107 4 min 46 s
#         can_you_solve_the_killer_robo_ants_riddle_dan_finkel  9.24M  3.91G  1.76M   450K 20181009 4 min 51 s
# the_surprising_reason_you_feel_awful_when_you_re_sick_marco_  7.36M  3.92G  2.64M   450K 20160419 5 min 0 s
# jellyfish_predate_dinosaurs_how_have_they_survived_so_long_d  11.0M  3.93G  2.19M   448K 20170328 5 min 25 s
#    what_is_mccarthyism_and_how_did_it_happen_ellen_schrecker  9.78M  3.94G  2.19M   448K 20170314 5 min 42 s
#        the_surprising_reasons_animals_play_dead_tierney_thys  7.38M  3.94G  1.75M   448K 20180416 4 min 46 s
# the_japanese_folktale_of_the_selfish_scholar_iseult_gillespi  14.7M  3.96G   886K   443K 20200914 4 min 59 s
#         history_vs_henry_viii_mark_robinson_and_alex_gendler  7.82M  3.97G  1.30M   443K 20181112 5 min 24 s
# would_you_opt_for_a_life_with_no_pain_hayley_levitt_and_beth  6.52M  3.97G  2.59M   441K 20151117 4 min 9 s
#  why_is_herodotus_called_the_father_of_history_mark_robinson  7.87M  3.98G  1.72M   441K 20171211 5 min 2 s
#       how_do_viruses_jump_from_animals_to_humans_ben_longdon  10.4M  3.99G  1.28M   437K 20190808 5 min 4 s
#                      why_is_glass_transparent_mark_miodownik  6.71M  4.00G  3.41M   436K 20140204 4 min 7 s
# what_causes_panic_attacks_and_how_can_you_prevent_them_cindy  17.4M  4.01G   872K   436K 20201008 5 min 22 s
#       can_you_solve_the_demon_dance_party_riddle_edwin_meyer  14.4M  4.03G   435K   435K 20210223 5 min 5 s
#                 what_happens_during_a_stroke_vaibhav_goswami  10.5M  4.04G  1.70M   435K 20180201 4 min 59 s
#                how_do_antidepressants_work_neil_r_jeyasingam  17.3M  4.05G   434K   434K 20210318 4 min 50 s
# a_day_in_the_life_of_a_teenage_samurai_constantine_n_vaporis  36.1M  4.09G   867K   433K 20200622 5 min 30 s
#                  a_brief_history_of_the_devil_brian_a_pavlac  17.4M  4.11G   432K   432K 20210330 5 min 6 s
#  exploring_other_dimensions_alex_rosenthal_and_george_zaidan  8.57M  4.12G  3.79M   431K 20130717 4 min 48 s
#                how_do_investors_choose_stocks_richard_coffin  15.1M  4.13G   431K   431K 20201110 5 min 1 s
#                 history_vs_christopher_columbus_alex_gendler  10.0M  4.14G  3.35M   429K 20141013 5 min 54 s
# how_many_ways_are_there_to_prove_the_pythagorean_theorem_bet  7.39M  4.15G  2.09M   429K 20170911 5 min 16 s
# can_100_renewable_energy_power_the_world_federico_rosei_and_  9.36M  4.16G  1.67M   429K 20171207 5 min 54 s
#                 can_you_solve_the_honeybee_riddle_dan_finkel  17.3M  4.17G   854K   427K 20200730 5 min 32 s
#         can_you_solve_the_riddle_and_escape_hades_dan_finkel  15.3M  4.19G   853K   427K 20201013 4 min 59 s
#                        are_ghost_ships_real_peter_b_campbell  11.7M  4.20G  2.08M   427K 20170228 5 min 0 s
#                        history_vs_richard_nixon_alex_gendler  9.98M  4.21G  2.91M   426K 20150212 5 min 39 s
#               what_caused_the_french_revolution_tom_mullaney  13.9M  4.22G  2.49M   426K 20161027 5 min 38 s
# what_happens_if_you_cut_down_all_of_a_city_s_trees_stefan_al  14.9M  4.24G   850K   425K 20200424 5 min 25 s
#  how_do_nuclear_power_plants_work_m_v_ramana_and_sajan_saini  11.5M  4.25G  2.07M   424K 20170508 8 min 6 s
#    is_there_any_truth_to_the_king_arthur_legends_alan_lupack  15.0M  4.26G  1.65M   423K 20180911 5 min 42 s
# what_really_happened_to_the_library_of_alexandria_elizabeth_  8.42M  4.27G  1.65M   422K 20180814 4 min 52 s
#                  can_a_black_hole_be_destroyed_fabio_pacucci  16.3M  4.29G  1.23M   420K 20190516 5 min 6 s
#        what_happens_when_you_remove_the_hippocampus_sam_kean  7.69M  4.30G  3.28M   420K 20140826 5 min 25 s
#   why_are_airplanes_slower_than_they_used_to_be_alex_gendler  14.9M  4.31G   418K   418K 20210415 4 min 58 s
#       why_do_you_get_a_fever_when_you_re_sick_christian_moro  19.7M  4.33G   417K   417K 20201112 5 min 37 s
#          how_to_make_your_writing_suspenseful_victoria_smith  8.44M  4.34G  1.63M   416K 20171031 4 min 35 s
#                         the_history_of_marriage_alex_gendler  8.24M  4.35G  3.24M   415K 20140213 4 min 43 s
#                 will_we_ever_be_able_to_teleport_sajan_saini  17.3M  4.36G  2.02M   414K 20170731 5 min 37 s
#          why_do_airlines_sell_too_many_tickets_nina_klietsch  6.11M  4.37G  2.02M   413K 20161220 4 min 59 s
#             the_taino_myth_of_the_cursed_creator_bill_keegan  10.9M  4.38G   825K   412K 20191104 3 min 45 s
#  the_japanese_myth_of_the_trickster_raccoon_iseult_gillespie  16.6M  4.39G   412K   412K 20210125 3 min 36 s
# the_myth_of_the_sampo_an_infinite_source_of_fortune_and_gree  11.9M  4.41G  1.20M   411K 20190923 5 min 15 s
# building_the_world_s_largest_and_most_controversial_power_pl  22.3M  4.43G   411K   411K 20201210 5 min 37 s
#          the_wacky_history_of_cell_theory_lauren_royal_woods  15.4M  4.44G  4.01M   410K 20120604 6 min 11 s
# can_you_survive_nuclear_fallout_brooke_buddemeier_and_jessic  8.90M  4.45G  1.19M   407K 20190108 5 min 24 s
#                        the_science_of_spiciness_rose_eveleth  6.03M  4.46G  3.16M   405K 20140310 3 min 54 s
# can_you_outsmart_the_fallacy_that_fooled_a_generation_of_doc  19.7M  4.48G   809K   405K 20200810 5 min 30 s
#              can_you_solve_the_alien_probe_riddle_dan_finkel  8.42M  4.49G  1.58M   405K 20180924 5 min 8 s
#         the_myth_of_jason_and_the_argonauts_iseult_gillespie  13.5M  4.50G  1.19M   405K 20190827 5 min 14 s
#           the_hidden_meanings_of_yin_and_yang_john_bellaimey  13.5M  4.51G  3.54M   403K 20130802 4 min 9 s
#                            how_do_crystals_work_graham_baird  12.4M  4.52G  1.17M   399K 20190618 5 min 6 s
#      check_your_intuition_the_birthday_problem_david_knuffke  13.3M  4.54G  1.95M   399K 20170504 5 min 6 s
#   what_percentage_of_your_brain_do_you_use_richard_e_cytowic  8.93M  4.55G  3.11M   399K 20140130 5 min 15 s
#                        what_causes_constipation_heba_shaheed  5.30M  4.55G  1.55M   396K 20180507 3 min 32 s
# are_you_a_body_with_a_mind_or_a_mind_with_a_body_maryam_alim  10.6M  4.56G  1.93M   396K 20170925 6 min 9 s
#         football_physics_the_impossible_free_kick_erez_garty  7.58M  4.57G  2.70M   395K 20150615 3 min 32 s
#                 the_science_of_skin_color_angela_koine_flynn  9.01M  4.58G  2.31M   394K 20160216 4 min 53 s
#            how_does_your_body_know_you_re_full_hilary_coller  8.23M  4.59G  1.53M   392K 20171113 4 min 33 s
#     the_world_s_biggest_battery_looks_nothing_like_a_battery  19.3M  4.60G   390K   390K 20210222 5 min 15 s
#            the_wild_world_of_carnivorous_plants_kenny_coogan  7.90M  4.61G  1.14M   390K 20190411 5 min 10 s
#                      the_life_cycle_of_a_t_shirt_angel_chang  12.3M  4.62G  1.90M   390K 20170905 6 min 3 s
#                      the_magic_of_vedic_math_gaurav_tekriwal  19.2M  4.64G  3.42M   390K 20130416 9 min 44 s
#                    how_computer_memory_works_kanawat_senanan  13.2M  4.66G  2.28M   389K 20160510 5 min 4 s
#                 three_ways_the_universe_could_end_venus_keus  7.53M  4.66G  1.14M   388K 20190219 4 min 46 s
# why_good_ideas_get_trapped_in_the_valley_of_death_and_how_to  16.6M  4.68G   386K   386K 20210406 5 min 9 s
#            how_rollercoasters_affect_your_body_brian_d_avery  9.21M  4.69G  1.51M   386K 20181029 5 min 1 s
# the_imaginary_king_who_changed_the_real_world_matteo_salvado  12.1M  4.70G   771K   385K 20200319 5 min 33 s
#                 how_to_spot_a_misleading_graph_lea_gaslowitz  8.34M  4.71G  1.88M   384K 20170706 4 min 9 s
#       why_should_you_read_the_handmaid_s_tale_naomi_r_mercer  11.2M  4.72G  1.50M   384K 20180308 5 min 4 s
#      the_physics_of_the_hardest_move_in_ballet_arleen_sugano  7.90M  4.73G  2.25M   383K 20160322 4 min 16 s
#         why_do_we_harvest_horseshoe_crab_blood_elizabeth_cox  7.50M  4.73G  1.87M   382K 20170921 4 min 45 s
#                   the_worlds_largest_organism_alex_rosenthal  23.3M  4.76G   380K   380K 20201207 6 min 27 s
#            a_brief_history_of_banned_numbers_alessandra_king  7.66M  4.76G  1.85M   380K 20170926 4 min 42 s
#      why_is_pneumonia_so_dangerous_eve_gaus_and_vanessa_ruiz  15.3M  4.78G   379K   379K 20201130 4 min 27 s
#                    how_aspirin_was_discovered_krishna_sudhir  11.6M  4.79G  1.85M   379K 20171002 5 min 44 s
#  how_to_use_rhetoric_to_get_what_you_want_camille_a_langston  6.38M  4.80G  2.22M   379K 20160920 4 min 29 s
# how_a_single_celled_organism_almost_wiped_out_life_on_earth_  7.87M  4.80G  2.21M   378K 20160811 4 min 13 s
#               the_wicked_wit_of_jane_austen_iseult_gillespie  15.8M  4.82G  1.10M   376K 20190321 5 min 0 s
# how_one_scientist_averted_a_national_health_crisis_andrea_to  13.0M  4.83G  1.47M   376K 20180607 5 min 31 s
#               a_day_in_the_life_of_an_aztec_midwife_kay_read  7.59M  4.84G   749K   375K 20200512 4 min 35 s
#          why_should_you_read_james_joyce_s_ulysses_sam_slote  18.6M  4.86G  1.83M   374K 20171024 5 min 58 s
# the_meaning_of_life_according_to_simone_de_beauvoir_iseult_g  12.3M  4.87G   748K   374K 20200310 5 min 10 s
#                the_rise_of_the_ottoman_empire_mostafa_minawi  21.3M  4.89G   373K   373K 20210121 5 min 14 s
#                           how_smart_are_dolphins_lori_marino  9.95M  4.90G  2.55M   372K 20150831 4 min 50 s
#          sex_determination_more_complicated_than_you_thought  17.4M  4.92G  3.62M   371K 20120423 5 min 45 s
# how_can_you_change_someone_s_mind_hint_facts_aren_t_always_e  10.5M  4.93G  1.45M   370K 20180726 4 min 39 s
#                  why_is_mount_everest_so_tall_michele_koppes  7.35M  4.93G  2.17M   370K 20160407 4 min 52 s
#                         is_time_travel_possible_colin_stuart  11.5M  4.95G  3.25M   370K 20131021 5 min 3 s
#           a_day_in_the_life_of_a_celtic_druid_philip_freeman  15.0M  4.96G  1.08M   369K 20190917 4 min 30 s
#               what_is_deja_vu_what_is_deja_vu_michael_molina  5.50M  4.97G  3.24M   369K 20130828 3 min 54 s
# ...
#       meet_global_corruption_s_hidden_players_charmian_gooch  31.3M  23.0G  8.53K    970 20130823 14 min 30 s
#                         a_giant_bubble_for_debate_liz_diller  18.5M  23.1G  8.50K    966 20130419 12 min 6 s
#                    the_4_commandments_of_cities_eduardo_paes  22.6M  23.1G  8.44K    960 20130712 12 min 21 s
#                 what_fear_can_teach_us_karen_thompson_walker  25.4M  23.1G  8.30K    944 20130517 11 min 30 s
#                      trusting_the_ensemble_charles_hazlewood  52.0M  23.2G  8.25K    939 20130809 19 min 36 s
#                     we_need_better_drugs_now_francis_collins  25.9M  23.2G  8.17K    929 20130830 14 min 40 s
#      what_we_re_learning_from_online_education_daphne_koller  40.9M  23.2G  8.16K    928 20130614 20 min 40 s
#                   mining_minerals_from_seawater_damian_palin  4.76M  23.2G  8.13K    925 20130705 3 min 1 s
#     weaving_narratives_in_museum_galleries_thomas_p_campbell  34.8M  23.3G  8.00K    910 20130511 16 min 36 s
#           what_we_re_learning_from_5000_brains_read_montague  26.2M  23.3G  7.92K    901 20130531 13 min 23 s
#                        texting_that_saves_lives_nancy_lublin  12.3M  23.3G  7.82K    889 20130712 5 min 24 s
#                         shape_shifting_dinosaurs_jack_horner  36.1M  23.3G  7.48K    850 20130815 18 min 22 s
#                      why_i_hold_on_to_my_grandmother_s_tales  13.0M  23.3G  3.31K    847 20180117 7 min 8 s
#                            click_your_fortune_episode_3_demo  5.18M  23.4G  7.32K    833 20130807 3 min 31 s
#           obesity_hunger_1_global_food_issue_ellen_gustafson  15.4M  23.4G  7.24K    823 20130801 16 min 34 s
#          a_broken_body_isn_t_a_broken_person_janine_shepherd  34.8M  23.4G  7.16K    815 20130528 18 min 57 s
#           ultrasound_surgery_healing_without_cuts_yoav_medan  30.7M  23.4G  7.07K    804 20130719 16 min 13 s
#                how_to_defend_earth_from_asteroids_phil_plait  22.7M  23.5G  7.06K    803 20130808 14 min 16 s
#                          how_to_buy_happiness_michael_norton  17.8M  23.5G  7.04K    800 20130821 10 min 58 s
#        the_case_for_collaborative_consumption_rachel_botsman  29.1M  23.5G  7.02K    798 20130717 16 min 34 s
#                       let_s_teach_kids_to_code_mitch_resnick  29.1M  23.5G  7.01K    798 20130424 16 min 48 s
#                            a_doctor_s_touch_abraham_verghese  38.3M  23.6G  7.00K    796 20130816 18 min 32 s
#              a_whistleblower_you_haven_t_heard_geert_chatrou  21.9M  23.6G  6.99K    795 20130815 11 min 56 s
#     let_s_put_birth_control_back_on_the_agenda_melinda_gates  55.2M  23.6G  6.92K    787 20130605 25 min 36 s
#                    how_we_found_the_giant_squid_edith_widder  15.2M  23.7G  6.89K    784 20130830 8 min 38 s
#                a_civil_response_to_violence_emiliano_salinas  20.4M  23.7G  6.84K    777 20130808 12 min 17 s
#                       re_examining_the_remix_lawrence_lessig  28.9M  23.7G  6.79K    772 20130801 18 min 45 s
#                   a_plane_you_can_drive_anna_mracek_dietrich  19.5M  23.7G  6.79K    772 20130809 9 min 37 s
#               the_flavors_of_life_through_the_eyes_of_a_chef  17.4M  23.7G  2.99K    765 20171130 6 min 39 s
#                      the_right_time_to_second_guess_yourself  22.4M  23.8G  3.72K    762 20170810 11 min 56 s
#                 pool_medical_patents_save_lives_ellen_t_hoen  18.6M  23.8G  6.70K    762 20130428 11 min 16 s
#      let_s_transform_energy_with_natural_gas_t_boone_pickens  34.6M  23.8G  6.68K    760 20130719 19 min 42 s
# what_nonprofits_can_learn_from_coca_cola_melinda_french_gate  33.8M  23.8G  6.66K    757 20130815 16 min 28 s
#                             kids_need_structure_colin_powell  33.4M  23.9G  6.63K    754 20130401 17 min 46 s
#                      how_you_can_help_fight_pediatric_cancer  14.4M  23.9G  3.62K    741 20170608 8 min 6 s
#            a_mini_robot_powered_by_your_phone_keller_rinaudo  12.0M  23.9G  6.46K    735 20130823 5 min 54 s
# unlock_the_intelligence_passion_greatness_of_girls_leymah_gb  44.7M  24.0G  6.45K    733 20130712 20 min 28 s
#                          meet_the_water_canary_sonaar_luthra  5.73M  24.0G  6.41K    729 20130726 3 min 37 s
#      a_universal_translator_for_surgeons_steven_schwaitzberg  19.3M  24.0G  6.34K    721 20130519 11 min 41 s
#                a_vision_of_crimes_in_the_future_marc_goodman  20.6M  24.0G  6.33K    720 20130628 8 min 44 s
#        the_future_race_car_150mph_and_no_driver_chris_gerdes  29.8M  24.0G  6.32K    719 20130829 10 min 47 s
#  how_do_you_save_a_shark_you_know_nothing_about_simon_berrow  35.7M  24.1G  6.29K    715 20130626 16 min 46 s
#            what_we_learn_before_we_re_born_annie_murphy_paul  21.3M  24.1G  6.22K    707 20130809 8 min 44 s
#              a_father_daughter_dance_in_prison_angela_patton  22.3M  24.1G  5.43K    695 20131211 8 min 48 s
#          the_good_news_on_poverty_yes_there_s_good_news_bono  24.9M  24.1G  6.09K    693 20130823 13 min 57 s
#                      a_prosthetic_arm_that_feels_todd_kuiken  38.2M  24.2G  6.02K    685 20130809 18 min 51 s
#   sometimes_it_s_good_to_give_up_the_driver_s_seat_baba_shiv  24.8M  24.2G  5.93K    675 20130501 9 min 47 s
#                   my_friend_richard_feynman_leonard_susskind  27.6M  24.2G  5.84K    664 20130815 14 min 41 s
#                     1000_tedtalks_6_words_sebastian_wernicke  13.3M  24.2G  5.80K    660 20130815 7 min 33 s
#                           before_i_die_i_want_to_candy_chang  11.3M  24.2G  5.69K    646 20130614 6 min 19 s
#                             a_child_of_the_state_lemn_sissay  29.0M  24.3G  5.00K    640 20131211 15 min 36 s
#          could_the_sun_be_good_for_your_heart_richard_weller  23.7M  24.3G  5.63K    640 20130325 12 min 59 s
#         experiments_that_hint_of_longer_lives_cynthia_kenyon  31.1M  24.3G  5.62K    639 20130809 16 min 23 s
#                using_nature_to_grow_batteries_angela_belcher  19.7M  24.3G  5.57K    634 20130815 10 min 25 s
#               energy_from_floating_algae_pods_jonathan_trent  30.6M  24.4G  5.47K    622 20130607 14 min 45 s
#                   lessons_from_death_row_inmates_david_r_dow  32.2M  24.4G  5.43K    618 20130821 18 min 16 s
#                                      where_is_home_pico_iyer  31.2M  24.4G  5.42K    617 20130823 14 min 4 s
#                       crowdsource_your_health_lucien_engelen  14.6M  24.4G  5.36K    610 20130815 6 min 12 s
#                    the_dance_of_the_dung_beetle_marcus_byrne  35.9M  24.5G  5.33K    605 20130429 17 min 8 s
#                         how_do_we_heal_medicine_atul_gawande  33.9M  24.5G  5.20K    591 20130419 19 min 19 s
#          mental_health_for_all_by_involving_all_vikram_patel  32.5M  24.5G  5.17K    587 20130607 12 min 22 s
#               how_healthy_living_nearly_killed_me_a_j_jacobs  14.8M  24.6G  5.11K    581 20130726 8 min 42 s
# science_is_for_everyone_kids_included_beau_lotto_and_amy_o_t  37.9M  24.6G  5.07K    577 20130524 15 min 25 s
# what_s_a_snollygoster_a_short_lesson_in_political_speak_mark  15.6M  24.6G  5.07K    577 20130410 6 min 39 s
#                       how_to_topple_a_dictator_srdja_popovic  37.9M  24.6G  5.02K    571 20130815 12 min 3 s
#               let_s_prepare_for_our_new_climate_vicki_arroyo  21.3M  24.7G  4.91K    559 20130524 10 min 38 s
# parkinson_s_depression_and_the_switch_that_might_turn_them_o  24.7M  24.7G  4.79K    544 20130612 15 min 34 s
#               neuroscience_game_theory_monkeys_colin_camerer  21.7M  24.7G  4.75K    540 20130619 13 min 49 s
#         michael_green_why_we_should_build_wooden_skyscrapers  23.7M  24.7G  4.73K    537 20130816 12 min 25 s
# a_choreographer_s_creative_process_in_real_time_wayne_mcgreg  43.7M  24.8G  4.65K    529 20130607 15 min 18 s
#       gaming_to_re_engage_boys_in_learning_ali_carr_chellman  24.5M  24.8G  4.64K    528 20130815 12 min 30 s
#                        how_to_expose_the_corrupt_peter_eigen  26.9M  24.8G  4.59K    522 20130725 16 min 12 s
#                    older_people_are_happier_laura_carstensen  20.9M  24.9G  4.58K    520 20130821 11 min 38 s
#                 the_voice_of_the_natural_world_bernie_krause  34.1M  24.9G  4.54K    516 20130816 14 min 51 s
# the_single_biggest_health_threat_women_face_noel_bairey_merz  31.5M  24.9G  4.51K    512 20130506 15 min 59 s
# we_the_people_and_the_republic_we_must_reclaim_lawrence_less  34.1M  24.9G  4.48K    509 20130823 18 min 22 s
#                   inside_the_egyptian_revolution_wael_ghonim  26.8M  25.0G  4.47K    508 20130725 10 min 7 s
#    a_clean_energy_proposal_race_to_the_top_jennifer_granholm  27.2M  25.0G  4.44K    505 20130830 12 min 41 s
#              the_shared_experience_of_absurdity_charlie_todd  32.2M  25.0G  4.37K    497 20130808 12 min 4 s
# could_tissue_engineering_mean_personalized_medicine_nina_tan  10.3M  25.0G  4.37K    496 20130517 6 min 19 s
#      how_i_taught_rats_to_sniff_out_land_mines_bart_weetjens  22.5M  25.1G  4.34K    493 20130801 12 min 11 s
#                                  my_immigration_story_tan_le  26.7M  25.1G  4.18K    475 20130815 12 min 16 s
#                           we_can_recycle_plastic_mike_biddle  22.4M  25.1G  4.14K    471 20130809 10 min 58 s
#                             embrace_the_remix_kirby_ferguson  17.5M  25.1G  4.02K    457 20130510 9 min 42 s
#               building_unimaginable_shapes_michael_hansmeyer  24.9M  25.2G  4.00K    455 20130621 11 min 7 s
#                           print_your_own_medicine_lee_cronin  5.44M  25.2G  3.97K    451 20130510 3 min 6 s
#                 how_to_look_inside_the_brain_carl_schoonover  9.04M  25.2G  3.92K    446 20130712 4 min 59 s
# how_to_step_up_in_the_face_of_disaster_caitria_morgan_o_neil  19.7M  25.2G  3.81K    433 20130829 9 min 23 s
#         a_prosthetic_eye_to_treat_blindness_sheila_nirenberg  19.1M  25.2G  3.79K    431 20130726 10 min 5 s
#                        advice_to_young_scientists_e_o_wilson  27.0M  25.2G  3.62K    412 20130705 14 min 56 s
#                the_strange_politics_of_disgust_david_pizarro  27.5M  25.3G  3.49K    397 20130408 14 min 2 s
#   what_if_our_healthcare_system_kept_us_healthy_rebecca_onie  29.6M  25.3G  3.35K    381 20130705 16 min 34 s
#                          what_s_left_to_explore_nathan_wolfe  14.1M  25.3G  3.34K    379 20130507 7 min 10 s
#                    the_100000_student_classroom_peter_norvig  11.4M  25.3G  3.32K    378 20130705 6 min 11 s
#                            tracking_the_trackers_gary_kovacs  11.2M  25.3G  3.32K    377 20130426 6 min 39 s
#       visualizing_the_medical_data_explosion_anders_ynnerman  25.7M  25.4G  3.31K    376 20130710 16 min 34 s
#                   fighting_with_non_violence_scilla_elworthy  13.8M  25.4G  3.25K    369 20130619 8 min 44 s
#      a_teacher_growing_green_in_the_south_bronx_stephen_ritz  31.5M  25.4G  3.24K    369 20130829 13 min 42 s
#        why_architects_need_to_use_their_ears_julian_treasure  16.5M  25.4G  3.15K    358 20130531 9 min 51 s
#              the_secret_lives_of_paintings_maurizio_seracini  21.8M  25.4G  2.94K    334 20130524 12 min 34 s
#                         what_s_your_200_year_plan_raghava_kk  20.8M  25.5G  2.93K    333 20130829 10 min 58 s
#                                  life_s_third_act_jane_fonda  26.0M  25.5G  2.91K    331 20130815 11 min 20 s
#    tracking_ancient_diseases_using_plaque_christina_warinner  9.05M  25.5G  2.88K    327 20130712 5 min 31 s
#                          be_an_artist_right_now_young_ha_kim  38.2M  25.5G  2.88K    327 20130612 16 min 57 s
#                        making_sense_of_maps_aris_venetikidis  36.0M  25.6G  2.83K    322 20130529 16 min 35 s
#             fighting_a_contagious_cancer_elizabeth_murchison  26.7M  25.6G  2.79K    317 20130816 13 min 3 s
# experiments_that_point_to_a_new_understanding_of_cancer_mina  36.7M  25.6G  2.77K    314 20130628 16 min 17 s
#              cloudy_with_a_chance_of_joy_gavin_pretor_pinney  18.9M  25.6G  2.76K    313 20130816 10 min 57 s
#                design_for_people_not_awards_timothy_prestero  20.8M  25.7G  2.74K    311 20130829 11 min 4 s
#                           the_art_of_creating_awe_rob_legato  50.3M  25.7G  2.59K    294 20130614 16 min 27 s
#               can_democracy_exist_without_trust_ivan_krastev  27.9M  25.7G  2.55K    289 20130510 14 min 4 s
#        the_promise_of_research_with_stem_cells_susan_solomon  24.4M  25.8G  2.45K    278 20130607 15 min 31 s
#                         a_census_of_the_ocean_paul_snelgrove  27.5M  25.8G  2.44K    277 20130719 16 min 47 s
#                finding_life_we_can_t_imagine_christoph_adami  41.4M  25.8G  2.38K    271 20130808 18 min 51 s
#                   your_phone_company_is_watching_malte_spitz  27.3M  25.9G  2.35K    267 20130621 10 min 10 s
#            welcome_to_the_genomic_revolution_richard_resnick  20.1M  25.9G  2.33K    265 20130703 11 min 2 s
#                          technology_s_epic_story_kevin_kelly  31.7M  25.9G  2.31K    263 20130725 16 min 32 s
#             freeing_energy_from_the_grid_justin_hall_tipping  30.8M  25.9G  2.23K    253 20130809 12 min 45 s
#                    a_girl_who_demanded_school_kakenya_ntaiya  44.2M  26.0G  2.18K    247 20130513 15 min 16 s
#                    excuse_me_may_i_rent_your_car_robin_chase  31.3M  26.0G  2.16K    245 20130517 12 min 24 s
#                  the_economic_injustice_of_plastic_van_jones  41.7M  26.0G  2.15K    244 20130808 17 min 33 s
#   how_open_data_is_changing_international_aid_sanjay_pradhan  31.8M  26.1G  2.12K    241 20130517 15 min 20 s
#                   demand_a_fair_trade_cell_phone_bandi_mbubi  15.2M  26.1G  2.04K    232 20130829 9 min 21 s
#          what_your_designs_say_about_you_sebastian_deterding  18.0M  26.1G  1.98K    224 20130821 12 min 20 s
#             demand_a_more_open_source_government_beth_noveck  41.4M  26.2G  1.94K    220 20130607 17 min 23 s
#                  a_story_about_knots_and_surgeons_ed_gavagan  24.7M  26.2G  1.88K    214 20130531 12 min 21 s
#                    let_s_pool_our_medical_data_john_wilbanks  32.1M  26.2G  1.82K    206 20130524 16 min 25 s
#      ethical_riddles_in_hiv_research_boghuma_kabisen_titanji  20.8M  26.2G  1.76K    200 20130605 11 min 10 s
#          a_test_for_parkinson_s_with_a_phone_call_max_little  12.5M  26.2G  1.75K    199 20130614 6 min 3 s
#          a_lab_the_size_of_a_postage_stamp_george_whitesides  26.3M  26.3G  1.68K    191 20130808 16 min 16 s
#              massive_scale_online_collaboration_luis_von_ahn  32.2M  26.3G  1.67K    189 20130808 16 min 39 s
#              a_short_intro_to_the_studio_school_geoff_mulgan  8.79M  26.3G  1.53K    174 20130816 6 min 16 s
#                          put_a_value_on_nature_pavan_sukhdev  31.9M  26.3G  1.50K    170 20130726 16 min 30 s
#        3_stories_of_local_eco_entrepreneurship_majora_carter  27.2M  26.4G  1.49K    169 20130725 16 min 34 s
#                                how_to_stop_torture_karen_tse  20.1M  26.4G  1.36K    154 20130809 8 min 44 s
# how_cyberattacks_threaten_real_world_peace_guy_philippe_gold  13.5M  26.4G  1.34K    152 20130808 9 min 23 s
# women_entrepreneurs_example_not_exception_gayle_tzemach_lemm  28.7M  26.4G  1.33K    151 20130815 13 min 16 s
#            the_day_i_turned_down_tim_berners_lee_ian_ritchie  10.7M  26.4G  1.33K    151 20130809 5 min 41 s
#                    the_arts_festival_revolution_david_binder  17.0M  26.5G  1.23K    140 20130517 9 min 4 s
#                      filming_democracy_in_ghana_jarreth_merz  18.0M  26.5G  1.14K    129 20130809 8 min 36 s
#                     there_are_no_scraps_of_men_alberto_cairo  36.4M  26.5G  1.08K    123 20130815 19 min 2 s
#                       digital_humanitarianism_paul_conneally  17.6M  26.5G  1.03K    117 20130626 10 min 57 s
#                an_unexpected_place_of_healing_ramona_pierson  33.8M  26.6G  1.02K    115 20130815 11 min 12 s
#               the_economic_case_for_preschool_timothy_bartik  31.1M  26.6G    727   80.0 20130815 15 min 48 s
#           let_s_crowdsource_the_world_s_goals_jamie_drummond  26.6M  26.6G    701   77.0 20130628 12 min 10 s

# %% [markdown]
# * Now determine the video ID's that we want in our new zim

# %%
print('We will include videos with views_per_year greater than %s'%boundary_views_per_year)
wanted_ids = []
sql = 'SELECT yt_id, title from video_info where views_per_year > ?'
db.c.execute(sql,[boundary_views_per_year,])
rows = db.c.fetchall()
for row in rows:
    wanted_ids.append(row['yt_id'])

#with open(HOME + '/zims/' + PROJECT_NAME + '/wanted_list.csv','w') as fp:
#    for row in rows:
#        fp.write('%s,%s\n'%(row['yt_id'],row['title'],))
# Out:
# We will include videos with views_per_year greater than 154211

# %% [raw]
# wanted_ids

# %% [markdown]
# * Now let's start building up the output directory

# %%
import shutil
# copy the default top level directories (these were in the zim's "-" directory )
print('Copying wanted folders and Videos to %s'%OUTPUT_DIR)
cpy_dirs = ['assets','cache','channels']
for d in cpy_dirs:
    shutil.rmtree(os.path.join(OUTPUT_DIR,d),ignore_errors=True)
    os.makedirs(os.path.join(OUTPUT_DIR,d))
    src = os.path.join(PROJECT_DIR,d)
    dest = os.path.join(OUTPUT_DIR,d)
    shutil.copytree(src,dest,dirs_exist_ok=True, symlinks=True)
# Out:
# Copying wanted folders and Videos to /library/www/html/zims/teded/output_tree

# %%
# Copy the videos selected by the wanted_ids list to output file
import shutil
for f in wanted_ids:
    if not os.path.isdir(os.path.join(OUTPUT_DIR,'videos',f)):
        os.makedirs(os.path.join(OUTPUT_DIR,'videos',f))
        src = os.path.join(PROJECT_DIR,'videos',f)
        dest = os.path.join(OUTPUT_DIR,'videos',f)
        shutil.copytree(src,dest,dirs_exist_ok=True)

# %%
#  Copy the files in the root directory
import shutil
for yt_id in wanted_ids:
    map_index_to_slug = get_zim_data(yt_id)
    if len(map_index_to_slug) > 0:
        title = map_index_to_slug['slug']
        src = os.path.join(PROJECT_DIR,title + '.html')
        dest = OUTPUT_DIR + '/' + title + '.html'
        if os.path.isfile(src) and not os.path.isfile(dest):
            shutil.copyfile(src,dest)
        else:
            print('src:%s'%src)

# %% [raw]
# wanted_ids

# %%
# There are essential files that are needed in the zim
needed = ['/favicon.jpg','/home.html','/profile.jpg']
for f in needed:
    cmd = '/bin/cp %s %s'%(PROJECT_DIR  + f,OUTPUT_DIR)
    subprocess.run(cmd,shell=True)

# %%
# Grab the meta data from the original zim "M" directory 
#   and create a script for zimwriterfs
def get_file_value(path):
    with open(path,'r') as fp:
        
        try:
            return fp.read()
        except:
            return ""
meta_data ={}
meta_file_names = os.listdir(PROJECT_DIR + '/M/')
for f in meta_file_names:
    meta_data[f] = get_file_value(PROJECT_DIR + '/M/' + f)
pprint(meta_data)
# Out:
# {'Counter': 'text/html=1852;image/jpeg=647;application/json=214;text/vtt=31701;video/webm=1851;image/webp=1237;application/javascript=83;text/plain=8;text/markdown=1;application/octet-stream=15;application/x-shockwave-flash=1;application/font-sfnt=6;text/css=6;image/png=2;image/svg+xml=1',
#  'Creator': 'Youtube Channel “TED-Ed”',
#  'Date': '2021-04-16',
#  'Description': 'TED-Ed’s commitment to creating lessons worth sharing is an '
#                 'extension of TED’s mission of spreading great ideas. Within '
#                 'TED-Ed’s growing library of TED-Ed animations, you will find '
#                 'carefully curated educational videos, many of which represent '
#                 'collaborations between talented educators and animators '
#                 'nominated through the TED-Ed website (ed.ted.com).  Want to '
#                 'suggest an idea for a TED-Ed animation or get involved with '
#                 'TED-Ed? Visit our website at: '
#                 'http://ed.ted.com/get_involved.  Also, consider donating to '
#                 'us on Patreon! By doing so, you directly support our mission '
#                 'and receive some pretty awesome rewards: '
#                 'https://www.patreon.com/teded  For more information on using '
#                 'TED for commercial purposes (e.g. employee learning, in a '
#                 'film, or in an online course), please submit a Media Request '
#                 'using this link: https://media-requests.ted.com/',
#  'IndexLanguage': 'eng',
#  'Language': 'eng',
#  'Name': 'teded_en_all',
#  'Publisher': 'Kiwix',
#  'Scraper': 'youtube2zim 2.1.13',
#  'Tags': '_category:ted;_videos:yes',
#  'Title': 'TED-Ed'}

# %%
# Write a new mapping from categories to vides (with some removed)
print('Creating a new mapping from Categories to videos within each category.')
outstr = ''
for cat in zim_category_js:
    outstr += 'var json_%s = [\n'%cat
    for video in range(len(zim_category_js[cat])):
        if zim_category_js[cat][video].get('id','') in wanted_ids:
            outstr += json.dumps(zim_category_js[cat][video],indent=1)
            outstr += ','
    outstr = outstr[:-1]
    outstr += '];\n'
with open(OUTPUT_DIR + '/assets/data.js','w') as fp:
    fp.write(outstr)
# Out:
# Creating a new mapping from Categories to videos within each category.

# %% [raw]
# mk_zim_cmd = """
# zimwriterfs --language=eng\
#             --welcome=A/home.html\
#             --favicon=I/favicon.jpg\
#             --title=teded_en_%s\
#             --description=\"TED-Ed Videos from YouTube Channel\"\
#             --creator='Youtube Channel “TED-Ed”'\
#             --publisher=IIAB\
#             --name=TED-Ed\
#              %s %s.zim"""%(PROJECT_NAME,OUTPUT_DIR,PROJECT_NAME)
# #with open(HOME + '/zims/' + PROJECT_NAME + '-zimwriter-cmd.sh','w') as fp:
# #    fp.write(mk_zim_cmd)

# %%
print('Creatng a new ZIM and Indexing it')

from pathlib import Path
from zimscraperlib.zim import make_zim_file
from glob import glob
from datetime import datetime

original_name = glob("%s/*.zim"%(SOURCE_DIR))
fname = os.path.basename(original_name[0].replace('all','top'))
print('fname:%s'%fname)
#sys.exit(1)

os.chdir(OUTPUT_DIR)
if not os.path.isfile(os.path.join(NEW_ZIM_DIR,fname)):
    make_zim_file(
        build_dir=Path(OUTPUT_DIR),
        fpath=Path(NEW_ZIM_DIR) / fname,
        name=fname,
        main_page= "home.html",
        favicon="favicon.jpg",
        title=meta_data['Title'],
        description=meta_data['Description'],
        language=meta_data['Language'],
        creator=meta_data['Creator'],
        publisher="Internet In A Box",
        tags=meta_data['Tags'],
        scraper=meta_data['Scraper'],
    )
# Out:
# Creatng a new ZIM and Indexing it
# fname:teded_en_top_2021-04.zim

# %%
# Dump the zim file to get the metadata accumulated during it's creation
cmd = f'zimdump dump --dir={PROOF_DIR} {NEW_ZIM_DIR}/{fname}'
subprocess.run(cmd,shell=True)
# Out:
# CompletedProcess(args='zimdump dump --dir=/library/www/html/zims/teded/proof /library/www/html/zims/teded/new-zim/teded_en_top_2021-04.zim', returncode=0)

# %%
# Create a dict with the counts of file mime types in the ZIM
with open(f'{PROOF_DIR}/M/Counter','r') as fp:
    counts = fp.read().split(';')
countdict = {}
for nibble in counts:
    nibble = nibble.split('=')
    countdict[nibble[0]] = nibble[1]
pprint(countdict)
# Out:
# {'application/csv': '40',
#  'application/javascript': '43',
#  'application/json': '213',
#  'application/octet-stream': '15',
#  'application/x-shockwave-flash': '1',
#  'font/sfnt': '6',
#  'image/jpeg': '43',
#  'image/png': '2',
#  'image/svg+xml': '1',
#  'image/webp': '820',
#  'text/css': '6',
#  'text/html': '833',
#  'text/markdown': '1',
#  'text/plain': '8',
#  'text/vtt': '18733',
#  'video/webm': '831'}

# %%
# Fetch the uuid from the new zim
cmd = f'zimdump info {NEW_ZIM_DIR}/{fname}'
infodump = subprocess.run(cmd,shell=True,capture_output=True)
lines = infodump.stdout.decode('utf-8').split('\n')
for line in lines:
    if line.split(' ')[0] == 'uuid:':
        uuid = line.split(' ')[1].strip()
if not uuid:
    print('failed to get uuid')
else:
    print("uuid:%s"%uuid)
# Out:
# uuid:2da1e31a-b962-86fd-d134-34eff6aa3b8f

# %%
# Create a catalog fragment for this video
import base64
uuidstr = uuid
CATALOG_FRAG_DIR = '/opt/iiab/iiab-content/catalogs/zim-cat-fragments'
WASABI_URL = 'https://s3.us-east-2.wasabisys.com'
# Maintain the order of the zim catalog
cat_keys = ['path','title','description','language','creator','publisher','tags','favicomMimeType',
           'favicon','date','articleCount','mediaCount','size','url','name','flavour']
outstr = '{"%s": {\n'%uuidstr
outstr += f'"path": "../library/zims/content/{fname}",\n'
outstr += f'"title": "{meta_data["Title"]}",\n'
outstr += f'"description": "{meta_data["Description"]}",\n'
outstr += f'"language": "{meta_data["Language"]}",\n'
outstr += f'"creator": "{meta_data["Creator"]}",\n'
outstr += f'"publisher": "Internet In A box",\n'
outstr += f'"tags": "{meta_data["Tags"]}",\n'
outstr += f'"faviconMimeType": "image/png",\n'
with open(PROJECT_DIR + '/favicon.jpg','rb') as fp:
    favi = fp.read()
b64 = base64.b64encode(favi)
outstr += f'"favicon": "{b64}",\n'
outstr += f'"date": "{meta_data["Date"]}",\n'
outstr += f'"articleCount": "{countdict["text/html"]}",\n'
outstr += f'"mediaCount": "{countdict["video/webm"]}",\n'
size = os.path.getsize(f'{NEW_ZIM_DIR}/{fname}')
outstr += f'"size": "{size}",\n'
outstr += f'"url": "{WASABI_URL}/{fname}",\n'
outstr += f'"name": "{meta_data["Name"]}",\n'
outstr += f'"flavour": ""\n'
outstr += '}}'
cat_fragment = '%s/%s'%(CATALOG_FRAG_DIR,fname.replace('.zim','.json'))
with open(cat_fragment,'w') as fp:
    fp.write(outstr)
print(outstr)
# Out:
# {"2da1e31a-b962-86fd-d134-34eff6aa3b8f": {
# "path": "../library/zims/content/teded_en_top_2021-04.zim",
# "title": "TED-Ed",
# "description": "TED-Ed’s commitment to creating lessons worth sharing is an extension of TED’s mission of spreading great ideas. Within TED-Ed’s growing library of TED-Ed animations, you will find carefully curated educational videos, many of which represent collaborations between talented educators and animators nominated through the TED-Ed website (ed.ted.com).  Want to suggest an idea for a TED-Ed animation or get involved with TED-Ed? Visit our website at: http://ed.ted.com/get_involved.  Also, consider donating to us on Patreon! By doing so, you directly support our mission and receive some pretty awesome rewards: https://www.patreon.com/teded  For more information on using TED for commercial purposes (e.g. employee learning, in a film, or in an online course), please submit a Media Request using this link: https://media-requests.ted.com/",
# "language": "eng",
# "creator": "Youtube Channel “TED-Ed”",
# "publisher": "Internet In A box",
# "tags": "_category:ted;_videos:yes",
# "faviconMimeType": "image/png",
# "favicon": "b'...'",
# "date": "2021-04-16",
# "articleCount": "833",
# "mediaCount": "831",
# "size": "10066478063",
# "url": "https://s3.us-east-2.wasabisys.com/teded_en_top_2021-04.zim",
# "name": "teded_en_all",
# "flavour": ""
# }}

# %%
# Now parse the file we just created to validate the json
with open(cat_fragment,'r') as fp:
    json_str = fp.read()
frag_dict = json.loads(json_str)

# %%
# Now recreate the iiab-zim-catalog by updating from zim fragments
from glob import glob
import json
CATALOG_FRAG_DIR = '/opt/iiab/iiab-content/catalogs/zim-cat-fragments'
ZIM_CATALOG = '/opt/iiab/iiab-content/catalogs/iiab-zim-cat.json'
with open(ZIM_CATALOG,'r') as zcat:
    zim_dict = json.loads(zcat.read())
frags = glob(CATALOG_FRAG_DIR + '/*.json')
for frag in frags:
    with open(frag,'r') as fp:
        frag_dict = json.loads(fp.read())
    zim_dict.update(frag_dict)
with open(ZIM_CATALOG,'w') as zcat:
    zcat.write(json.dumps(zim_dict,indent=2))
